# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def f(u,x):
    return [u[1], ((-1/(2*u[0]**2)) - (u[0]/(4*x**2)))]
y0= [3.3920e6,7.0681e-3]
xs= np.linspace(2.3995e8,20.321e14,6000)
us= odeint(f,y0,xs)
ys= us[:,0]
plt.plot(xs,ys,'r')
plt.xlabel('t/2GM')
plt.ylabel('r/2GM')
plt.title('using r = 10e12m & M = 100 solar mass')
plt.show()
# Out:
# /Users/pratibhajangra/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def f(u,x):
    return [u[1], ((-1/(2*u[0]**2)) - (u[0]/(4*x**2)))]
y0= [3.3920e6,7.0681e-3]
xs= np.linspace(2.3995e8,20.321e14,6000)
us= odeint(f,y0,xs)
ys= us[:,0]
plt.loglog(xs,ys,'r')
plt.xlabel('t/2GM')
plt.ylabel('r/2GM')
plt.title('using r = 10e12m & M = 100 solar mass')
plt.show()
# Out:
# /Users/pratibhajangra/opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/odepack.py:247: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

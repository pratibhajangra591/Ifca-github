# %%
# Final merger time for the reference systems as a function of the initial 
# angular momentum j0 for binaries without DM halos having Power Law PDF 
# in the PBH  mass range of 5 - 100 solar mass.

import numpy as np
import matplotlib.pyplot as plt
import imripy
from imripy import merger_system as ms
from scipy.interpolate import interp1d
from matplotlib.ticker import FormatStrFormatter
from scipy.optimize import curve_fit
from numpy import diff

plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})



π = np.pi
G = 4.4959e-15            #in units of M☉^-1 pc^3 yr^-2
c = 0.3068                #in units of pc yr^-1
ρ_eq = 3.1812e3           #in units of M☉ pc^-3 with ρ_eq=2.15368e-16 kg m^-3
t_m = 13.78e9             #in units of yrs corresponding to t_0=13.78Gyr
yr = 3.154e7              # in units of seconds
t_eq = 1.59246e12/yr      # in units of yr
M_solar = 1.989e30


# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   

    

    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 1.14e-3
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 1.6
        M = 5     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial * 1e11
j0_array = np.geomspace(1e-3, 5e-3, 10)
j0_ref_list_1 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_1 = np.zeros(len(j0_ref_list_1))
T_list = np.zeros(len(j0_ref_list_1))


for k, j0 in enumerate (j0_ref_list_1):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_1[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_1_PWR_1",  j0_ref_list_1,  tm_ref_list_1)

    
    
plt.loglog(j0_ref_list_1, tm_ref_list_1, '--o')


print(tm_ref_list_1)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.show()
# Out:
# a_initial=  0.00030902260841150623
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.999999499999875  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:534: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t_coal = t_coal * 48./19. / g(e_0)**4 * quad(lambda e: g(e)**4 *(1-e**2)**(5./2.) /e/(1. + 121./304. * e**2), 0., e_0, limit=100)[0]   # The inspiral time according to Maggiore (2007)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3435s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999992850151702  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6993s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999989775935948  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9406s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999985379900622  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2445s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999979093702372  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4615s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.999997010462595  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4209s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999957250509957  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2791s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999938869491951  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1092s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999912585144586  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2773s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.999987499921874  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2745s
# here
# [8.48342423e+12 9.22383887e+12 1.00181472e+13 1.08671786e+13
#  1.17708169e+13 1.27276774e+13 1.37349178e+13 1.47877882e+13
#  1.58794505e+13 1.70007200e+13]

# %%
# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   
   

    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 1.14e-3
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 1.6
        M = 5     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial * 1e11
j0_array = np.geomspace(5.1e-3, 1, 10)
j0_ref_list_2 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_2 = np.zeros(len(j0_ref_list_2))
T_list = np.zeros(len(j0_ref_list_2))


for k, j0 in enumerate (j0_ref_list_2):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_2[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_2_PWR_1",  j0_ref_list_2,  tm_ref_list_2)

    
    
plt.loglog(j0_ref_list_2, tm_ref_list_2, '--o')


print(tm_ref_list_2)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.savefig('tm_refvsj_i_ref.pdf', bbon_inches = 'tight')
plt.show()
# Out:
# a_initial=  0.00030902260841150623
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999869949154339  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4307s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9999579710700719  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.0305s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9998641694208956  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6190s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9995609719689087  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6543s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.998580504223825  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6686s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9954053390320782  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6061s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9850742315840324  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7263s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.9509201987591743  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5680s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco  with initial eccentricity 0.8310016713752333  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7216s
# here
# Evolving from  1.0729951680955077e+20  to  1.0 r_isco   on circular orbits  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 0.0430s
# here
# [1.71262270e+13 2.08495200e+13 2.41863854e+13 2.66339351e+13
#  2.80978682e+13 2.89569719e+13 3.02179201e+13 3.57961528e+13
#  5.85247273e+13 1.80067815e+14]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/merger_system.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((self.mass(r) + self.m2)/r**3)
# /tmp/ipykernel_114654/2390019642.py:134: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbon_inches" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('tm_refvsj_i_ref.pdf', bbon_inches = 'tight')

# %%
plt.figure(figsize = (12, 5))

x  = (j0_ref_list_1[0], j0_ref_list_1[1], j0_ref_list_1[2] )
y  = (tm_ref_list_1[0], tm_ref_list_1[1], tm_ref_list_1[2])

plt.loglog(x,y,'gd',  label='data')

p = np.polyfit(np.log(x),np.log(y),1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p,np.log(x))
plt.loglog(x, np.exp(z), 'r',  label='fit')
print("Slope and intercept of fitting function =", p) 

plt.xlabel('$j_{i}$', fontsize = 14)
plt.ylabel('final merger time / yr', fontsize = 14)
plt.title('Reference binary Without DM halos, Power Law PDF, $m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ', fontsize = 17, pad = 9)
plt.legend()
plt.show()


# So, the fitting function is t_final_mergertime = (10**32.98) * (j0**0.465)
# Out:
# Slope and intercept of fitting function = [ 0.46493127 32.9809451 ]

# %%
j0_array_3 = np.geomspace(1e-6, 1e-4, 10)

j0_ref_list_3 = j0_array_3.tolist()

def t_final_merger(j0):
    return  (10**32.98) * (j0**0.465) 
    
tm_ref_list_3 = np.zeros(len(j0_ref_list_3))

for i, j0 in enumerate(j0_ref_list_3):
    tm_ref_list_3[i] = t_final_merger(j0)
    

    
    

plt.loglog(j0_ref_list_3, tm_ref_list_3, 'g')
plt.xlabel('$j_{i}$')
plt.ylabel('final merger time/yr')
plt.show()


print("j0_lower_values =", j0_ref_list_3)
print('\v')
print("final merger time / yr =", tm_ref_list_3)


file = np.load('tmofjo_1_PWR_1.npz')
ji_ref_list_1 = file['arr_0']
tm_ref_list_1 = file['arr_1']


file = np.load('tmofjo_2_PWR_1.npz')
ji_ref_list_2 = file['arr_0']
tm_ref_list_2 = file['arr_1']



j_initial_list = j0_ref_list_1 + j0_ref_list_2 + j0_ref_list_3


t_1 =  np.append(tm_ref_list_1, tm_ref_list_2) 

t_final_list = np.append(t_1, tm_ref_list_3 )

a_initial=   3.0902e-4 # in units of pc


a_i_ref_PWR_1 = a_initial * 1e11

np.savez("tm_ofj0_PWR_1", a_i_ref_PWR_1, j_initial_list,  t_final_list)
# Out:
# j0_lower_values = [1e-06, 1.6681005372000591e-06, 2.782559402207126e-06, 4.641588833612782e-06, 7.742636826811277e-06, 1.2915496650148827e-05, 2.1544346900318823e-05, 3.5938136638046256e-05, 5.994842503189409e-05, 0.0001]
#
# final merger time / yr = [1.54881662e+30 1.96486779e+30 2.49268079e+30 3.16227766e+30
#  4.01174512e+30 5.08940095e+30 6.45654229e+30 8.19093224e+30
#  1.03912230e+31 1.31825674e+31]

# %%
# Final merger time for the reference systems as a function of the initial 
# angular momentum j0 for binaries without DM halos having Lognormal PDF 
# in the PBH  mass range of 5 - 100 solar mass.


# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   


    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 8.26e-4
    f = 0.85 * f_pbh
        
          
    def P(m):                  #Log-Normal PBH mass Distribution
        σ = 0.6
        m_c = 15               #in units of M☉, for PBHs mass range of m_min = 5 M☉ - m_max = 100 M☉ .
        return  (1/(σ * m * np.sqrt(2*π))) * np.exp(-(((np.log(m/m_c))**2)/(2*(σ**2))))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial 
j0_array = np.geomspace(1e-3, 5e-3, 10)
j0_ref_list_1 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_1 = np.zeros(len(j0_ref_list_1))
T_list = np.zeros(len(j0_ref_list_1))


for k, j0 in enumerate (j0_ref_list_1):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_1[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_1_Lgnml_1",  j0_ref_list_1,  tm_ref_list_1)

    
    
plt.loglog(j0_ref_list_1, tm_ref_list_1, '--o')


print(tm_ref_list_1)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.show()
# Out:
# a_initial=  4.5630866636401984e+17
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.999999499999875  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:534: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t_coal = t_coal * 48./19. / g(e_0)**4 * quad(lambda e: g(e)**4 *(1-e**2)**(5./2.) /e/(1. + 121./304. * e**2), 0., e_0, limit=100)[0]   # The inspiral time according to Maggiore (2007)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 5.3642s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999992850151702  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2477s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999989775935948  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8288s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999985379900622  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7478s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999979093702372  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1523s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.999997010462595  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0737s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999957250509957  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.5433s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999938869491951  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.5612s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999912585144586  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4447s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.999987499921874  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8716s
# here
# [3.59354138e+20 3.90717686e+20 4.24364237e+20 4.60328886e+20
#  4.98606015e+20 5.39139455e+20 5.81804680e+20 6.26403902e+20
#  6.72646356e+20 7.20142867e+20]

# %%
# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   

  

def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 8.26e-4
    f = 0.85 * f_pbh
        
          
    def P(m):                  #Log-Normal PBH mass Distribution
        σ = 0.6
        m_c = 15               #in units of M☉, for PBHs mass range of m_min = 5 M☉ - m_max = 100 M☉ .
        return  (1/(σ * m * np.sqrt(2*π))) * np.exp(-(((np.log(m/m_c))**2)/(2*(σ**2))))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial 
j0_array = np.geomspace(5.1e-3, 1, 10)
j0_ref_list_2 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_2 = np.zeros(len(j0_ref_list_2))
T_list = np.zeros(len(j0_ref_list_2))


for k, j0 in enumerate (j0_ref_list_2):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_2[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_2_Lgnml_1",  j0_ref_list_2,  tm_ref_list_2)

    
    
plt.loglog(j0_ref_list_2, tm_ref_list_2, '--o')


print(tm_ref_list_2)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.savefig('tm_refvsj_i_ref.pdf', bbon_inches = 'tight')
plt.show()
# Out:
# a_initial=  4.5630866636401984e+17
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999869949154339  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.5164s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9999579710700719  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0866s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9998641694208956  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3759s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9995609719689087  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3215s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.998580504223825  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3778s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9954053390320782  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.6574s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9850742315840324  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.6819s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.9509201987591743  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.9349s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco  with initial eccentricity 0.8310016713752333  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.7098s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco   on circular orbits  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0032s
# here
# Evolving from  1.5844050915417356e+30  to  1.0 r_isco   on circular orbits  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 0.0480s
# [7.25459299e+20 8.83176477e+20 1.02452450e+21 1.12820153e+21
#  1.19021298e+21 1.22660432e+21 1.28001748e+21 1.51630870e+21
#  2.47908110e+21 7.62759149e+21]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/merger_system.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((self.mass(r) + self.m2)/r**3)
# /tmp/ipykernel_114654/3626858093.py:134: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbon_inches" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('tm_refvsj_i_ref.pdf', bbon_inches = 'tight')

# %%
plt.figure(figsize = (12, 5))

x  = (j0_ref_list_1[0], j0_ref_list_1[1], j0_ref_list_1[2] )
y  = (tm_ref_list_1[0], tm_ref_list_1[1], tm_ref_list_1[2])

plt.loglog(x,y,'gd',  label='data')

p = np.polyfit(np.log(x),np.log(y),1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p,np.log(x))
plt.loglog(x, np.exp(z), 'r',  label='fit')
print("Slope and intercept of fitting function =", p) 

plt.xlabel('$j_{i}$', fontsize = 14)
plt.ylabel('final merger time / yr', fontsize = 14)
plt.title('Reference binary Without DM halos, Lognormal PDF, $m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ', fontsize = 17, pad = 9)
plt.legend()
plt.savefig('1Lgextrapolate.pdf', bbox_inches = 'tight')
plt.show()


# So, the fitting function is t_final_mergertime = (10**50.54) * (j0**0.465).
# Out:
# Slope and intercept of fitting function = [ 0.46493064 50.54264544]

# %%
j0_array_3 = np.geomspace(1e-6, 1e-4, 10)

j0_ref_list_3 = j0_array_3.tolist()

def t_final_merger(j0):
    return  (10**50.54) * (j0**0.465)
    
tm_ref_list_3 = np.zeros(len(j0_ref_list_3))

for i, j0 in enumerate(j0_ref_list_3):
    tm_ref_list_3[i] = t_final_merger(j0)
    

    

plt.loglog(j0_ref_list_3, tm_ref_list_3, 'g')
plt.xlabel('$j_{i}$')
plt.ylabel('final merger time/yr')
plt.show()


print("j0_lower_values =", j0_ref_list_3)
print('\v')
print("final merger time / yr =", tm_ref_list_3)


file = np.load('tmofjo_1_Lgnml_1.npz')
ji_ref_list_1 = file['arr_0']
tm_ref_list_1 = file['arr_1']


file = np.load('tmofjo_2_Lgnml_1.npz')
ji_ref_list_2 = file['arr_0']
tm_ref_list_2 = file['arr_1']



j_initial_list = j0_ref_list_1 + j0_ref_list_2 + j0_ref_list_3


t_1 =  np.append(tm_ref_list_1, tm_ref_list_2) 

t_final_list = np.append(t_1, tm_ref_list_3 )

a_initial = 4.5631e+17   # in units of pc


a_i_ref_Lgnml_1 = a_initial 

np.savez("tm_ofj0_Lgnml_1", a_i_ref_Lgnml_1, j_initial_list,  t_final_list)
# Out:
# j0_lower_values = [1e-06, 1.6681005372000591e-06, 2.782559402207126e-06, 4.641588833612782e-06, 7.742636826811277e-06, 1.2915496650148827e-05, 2.1544346900318823e-05, 3.5938136638046256e-05, 5.994842503189409e-05, 0.0001]
#
# final merger time / yr = [5.62341325e+47 7.13400375e+47 9.05037692e+47 1.14815362e+48
#  1.45657662e+48 1.84784980e+48 2.34422882e+48 2.97394775e+48
#  3.77282505e+48 4.78630092e+48]

# %%
# Final merger time for the reference systems as a function of the initial 
# angular momentum j0 for binaries without DM halos having Power Law PDF 
# in the PBH  mass range of 1e-3 - 100 solar mass.



# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   

    

    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 1.18
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 1.6
        M = 1e-3     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial * 1e11
j0_array = np.geomspace(1e-3, 5e-3, 10)
j0_ref_list_1 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_1 = np.zeros(len(j0_ref_list_1))
T_list = np.zeros(len(j0_ref_list_1))


for k, j0 in enumerate (j0_ref_list_1):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_1[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_1_PWR_2",  j0_ref_list_1,  tm_ref_list_1)

    
    
plt.loglog(j0_ref_list_1, tm_ref_list_1, '--o')


print(tm_ref_list_1)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.show()
# Out:
# a_initial=  2.6234321788884984e-05
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.999999499999875  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:534: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t_coal = t_coal * 48./19. / g(e_0)**4 * quad(lambda e: g(e)**4 *(1-e**2)**(5./2.) /e/(1. + 121./304. * e**2), 0., e_0, limit=100)[0]   # The inspiral time according to Maggiore (2007)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6805s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999992850151702  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8603s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999989775935948  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2198s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999985379900622  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2884s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999979093702372  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5314s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.999997010462595  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4284s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999957250509957  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5190s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999938869491951  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5946s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999912585144586  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4982s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.999987499921874  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3487s
# here
# [1.33423053e+12 1.45067925e+12 1.57560409e+12 1.70913550e+12
#  1.85125521e+12 2.00174545e+12 2.16015917e+12 2.32574937e+12
#  2.49744055e+12 2.67378822e+12]

# %%
# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   
   

    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 1.18
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 1.6
        M = 1e-3     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial * 1e11
j0_array = np.geomspace(5.1e-3, 1, 10)
j0_ref_list_2 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_2 = np.zeros(len(j0_ref_list_2))
T_list = np.zeros(len(j0_ref_list_2))


for k, j0 in enumerate (j0_ref_list_2):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_2[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_2_PWR_2",  j0_ref_list_2,  tm_ref_list_2)

    
    
plt.loglog(j0_ref_list_2, tm_ref_list_2, '--o')


print(tm_ref_list_2)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.savefig('tm_refvsj_i_ref.pdf', bbon_inches = 'tight')
plt.show()
# Out:
# a_initial=  2.6234321788884984e-05
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999869949154339  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5722s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9999579710700719  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1047s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9998641694208956  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3841s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9995609719689087  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7140s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.998580504223825  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6034s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9954053390320782  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7449s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9850742315840324  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7397s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.9509201987591743  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6646s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco  with initial eccentricity 0.8310016713752333  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6969s
# here
# Evolving from  9.109139510029509e+18  to  1.0 r_isco   on circular orbits  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 0.0505s
# here
# [2.69352733e+12 3.27910823e+12 3.80391373e+12 4.18885211e+12
#  4.41909219e+12 4.55420772e+12 4.75252335e+12 5.62983988e+12
#  9.20447641e+12 2.83201654e+13]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/merger_system.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((self.mass(r) + self.m2)/r**3)
# /tmp/ipykernel_114654/501428392.py:134: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbon_inches" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('tm_refvsj_i_ref.pdf', bbon_inches = 'tight')

# %%
plt.figure(figsize = (12, 5))

x  = (j0_ref_list_1[0], j0_ref_list_1[1], j0_ref_list_1[2] )
y  = (tm_ref_list_1[0], tm_ref_list_1[1], tm_ref_list_1[2])

plt.loglog(x,y,'gd',  label='data')

p = np.polyfit(np.log(x),np.log(y),1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p,np.log(x))
plt.loglog(x, np.exp(z), 'r',  label='fit')
print("Slope and intercept of fitting function =", p) 

plt.xlabel('$j_{i}$', fontsize = 14)
plt.ylabel('final merger time / yr', fontsize = 14)
plt.title('Reference binary Without DM halos, Power Law PDF, $m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ', fontsize = 17, pad = 9)
plt.legend()
plt.show()


# So, the fitting function is t_final_mergertime = (10**31.13) * (j0**0.465)
# Out:
# Slope and intercept of fitting function = [ 0.46493127 31.13118569]

# %%
j0_array_3 = np.geomspace(1e-6, 1e-4, 10)

j0_ref_list_3 = j0_array_3.tolist()

def t_final_merger(j0):
    return  (10**31.13) * (j0**0.465) 
    
tm_ref_list_3 = np.zeros(len(j0_ref_list_3))

for i, j0 in enumerate(j0_ref_list_3):
    tm_ref_list_3[i] = t_final_merger(j0)
    

    
    

plt.loglog(j0_ref_list_3, tm_ref_list_3, 'g')
plt.xlabel('$j_{i}$')
plt.ylabel('final merger time/yr')
plt.show()


print("j0_lower_values =", j0_ref_list_3)
print('\v')
print("final merger time / yr =", tm_ref_list_3)


file = np.load('tmofjo_1_PWR_2.npz')
ji_ref_list_1 = file['arr_0']
tm_ref_list_1 = file['arr_1']


file = np.load('tmofjo_2_PWR_2.npz')
ji_ref_list_2 = file['arr_0']
tm_ref_list_2 = file['arr_1']



j_initial_list = j0_ref_list_1 + j0_ref_list_2 + j0_ref_list_3


t_1 =  np.append(tm_ref_list_1, tm_ref_list_2) 

t_final_list = np.append(t_1, tm_ref_list_3 )

a_initial=  2.6234e-05 # in units of pc


a_i_ref_PWR_2 = a_initial * 1e11

np.savez("tm_ofj0_PWR_2", a_i_ref_PWR_2, j_initial_list,  t_final_list)
# Out:
# j0_lower_values = [1e-06, 1.6681005372000591e-06, 2.782559402207126e-06, 4.641588833612782e-06, 7.742636826811277e-06, 1.2915496650148827e-05, 2.1544346900318823e-05, 3.5938136638046256e-05, 5.994842503189409e-05, 0.0001]
#
# final merger time / yr = [2.18776162e+28 2.77544952e+28 3.52100520e+28 4.46683592e+28
#  5.66674061e+28 7.18896992e+28 9.12010839e+28 1.15699993e+29
#  1.46779927e+29 1.86208714e+29]

# %%
# Final merger time for the reference systems as a function of the initial 
# angular momentum j0 for binaries without DM halos having Lognormal PDF 
# in the PBH  mass range of 1e-3 - 100 solar mass.


# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   


    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 1.01e-3
    f = 0.85 * f_pbh
        
          
    def P(m):                  #Log-Normal PBH mass Distribution
        σ = 0.6
        m_c = 15               #in units of M☉, for PBHs mass range of m_min = 5 M☉ - m_max = 100 M☉ .
        return  (1/(σ * m * np.sqrt(2*π))) * np.exp(-(((np.log(m/m_c))**2)/(2*(σ**2))))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial 
j0_array = np.geomspace(1e-3, 5e-3, 10)
j0_ref_list_1 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_1 = np.zeros(len(j0_ref_list_1))
T_list = np.zeros(len(j0_ref_list_1))


for k, j0 in enumerate (j0_ref_list_1):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_1[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_1_Lgnml_2",  j0_ref_list_1,  tm_ref_list_1)

    
    
plt.loglog(j0_ref_list_1, tm_ref_list_1, '--o')


print(tm_ref_list_1)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.show()
# Out:
# a_initial=  2.854054679587045e+17
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.999999499999875  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:534: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   t_coal = t_coal * 48./19. / g(e_0)**4 * quad(lambda e: g(e)**4 *(1-e**2)**(5./2.) /e/(1. + 121./304. * e**2), 0., e_0, limit=100)[0]   # The inspiral time according to Maggiore (2007)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4373s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999992850151702  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9437s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999989775935948  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8778s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999985379900622  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6954s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999979093702372  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0505s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.999997010462595  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7075s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999957250509957  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.6483s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999938869491951  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1775s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999912585144586  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0664s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.999987499921874  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9000s
# here
# [2.52740763e+20 2.74799486e+20 2.98463723e+20 3.23758204e+20
#  3.50679355e+20 3.79187579e+20 4.09194599e+20 4.40562110e+20
#  4.73085327e+20 5.06490861e+20]

# %%
# Final merger time for the reference systems as a function of the initial 
# angular momentum j0 for binaries without DM halos having Lognormal PDF 
# in the PBH  mass range of 1e-3 - 100 solar mass.


# Definition of the reference binary system with m_1 = 1 M☉ and m_2 = 1e-3 M☉.
bin_centres = np.geomspace(1e-3, 1, 5)
bin_edges = np.sqrt(bin_centres[:-1]*bin_centres[1:])


ratio = bin_edges[1]/bin_edges[0] 
bin_edges = np.append(bin_edges[0]/ratio, bin_edges) 
bin_edges = np.append(bin_edges, bin_edges[-1]*ratio) 


deltas = np.diff(bin_edges)
Δ_1_list = deltas.tolist()
Δ_2_list = deltas.tolist()

m_1 = np.geomspace(1e-3, 1, 5)
m_2 = np.geomspace(1e-3, 1, 5)
m_1_list = m_1.tolist()
m_2_list = m_2.tolist()   


    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 1.01e-3
    f = 0.85 * f_pbh
        
          
    def P(m):                  #Log-Normal PBH mass Distribution
        σ = 0.6
        m_c = 15               #in units of M☉, for PBHs mass range of m_min = 5 M☉ - m_max = 100 M☉ .
        return  (1/(σ * m * np.sqrt(2*π))) * np.exp(-(((np.log(m/m_c))**2)/(2*(σ**2))))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return (0.0965*λ(m_1,m_2,Δ_1,Δ_2) + 0.0165*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_initial = a(m_1_list[-1], m_2_list[0], Δ_1_list[-1], Δ_2_list[0])


print("a_initial= ", a_initial)


# Setting initial and final conditions of the binary evolution for an eccentric orbit
a_i_ref = a_initial 
j0_array = np.geomspace(5.1e-3, 1, 10)
j0_ref_list_2 = j0_array.tolist()





plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)






tm_ref_list_2 = np.zeros(len(j0_ref_list_2))
T_list = np.zeros(len(j0_ref_list_2))


for k, j0 in enumerate (j0_ref_list_2):
    m_bar = 1
    m1 =  m_bar * ms.solar_mass_to_pc  
    m2 = 1e-3 * ms.solar_mass_to_pc   
    D_luminosity = 5e8              
    ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))   
    r_spike = 1  # in parsecs, Choosen by choice
    alpha = 9/4
    rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  
    spike = imripy.halo.Spike(rho_spike, r_spike, alpha)
    sp = ms.SystemProp(m1, m2, spike, D_luminosity)
    a_fin = sp.r_isco()      # Choosen equal to r_icso
    R_fin = sp.r_isco()      # The final condition for the evolution
    e0 = np.sqrt(1 -(j0**2))
    
    
    m_2_ref = 1 # in units of solar mass
    T = 1e-5 * (t_m * ms.year_to_pc ) * ((m2/m_2_ref)**(-1))
    
    ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref , e0,  a_fin = R_fin, t_fin = T)
    tm = ev_ecc.t[-1]
    
    print("here")
    while np.isclose(T, tm) == True: 
        T = T * 1000
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a_i_ref, e0,  a_fin = R_fin, t_fin = T)
        tm = ev_ecc.t[-1]
        
            
            
    tm_ref_list_2[k] = tm/ms.year_to_pc
    T_list[k] =  T/ms.year_to_pc
      
    
   
   
    
    np.savez("tmofjo_2_Lgnml_2",  j0_ref_list_2,  tm_ref_list_2)

    
    
plt.loglog(j0_ref_list_2, tm_ref_list_2, '--o')


print(tm_ref_list_2)
    

plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.show()
# Out:
# a_initial=  2.854054679587045e+17
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999869949154339  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2415s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9999579710700719  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2308s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9998641694208956  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9106s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9995609719689087  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7446s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.998580504223825  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.8303s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9954053390320782  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0702s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9850742315840324  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4690s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.9509201987591743  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2974s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco  with initial eccentricity 0.8310016713752333  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3777s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco   on circular orbits  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# The solver successfully reached the end of the integration interval.
#  -> Evolution took 0.0038s
# here
# Evolving from  9.909912081899462e+29  to  1.0 r_isco   on circular orbits  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 0.0480s
# [5.10229714e+20 6.21155132e+20 7.20568111e+20 7.93486181e+20
#  8.37100196e+20 8.62694868e+20 9.00261262e+20 1.06644953e+21
#  1.74358622e+21 5.36463407e+21]
# /home/pratibhajangra/Desktop/Work/imripy-main/src/imripy/merger_system.py:202: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((self.mass(r) + self.m2)/r**3)

# %%
plt.figure(figsize = (12, 5))

x  = (j0_ref_list_1[0], j0_ref_list_1[1], j0_ref_list_1[2] )
y  = (tm_ref_list_1[0], tm_ref_list_1[1], tm_ref_list_1[2])

plt.loglog(x,y,'gd',  label='data')

p = np.polyfit(np.log(x), np.log(y),1)  # F(x) = (x**m)(10**b) with m = slope, b = intercept.
z = np.polyval(p, np.log(x))
plt.loglog(x, np.exp(z), 'r',  label='fit')
print("Slope and intercept of fitting function =", p) 

plt.xlabel('$j_{i}$', fontsize = 14)
plt.ylabel('final merger time / yr', fontsize = 14)
plt.title('Reference binary Without DM halos, Lognormal PDF, $m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ', fontsize = 17, pad = 9)
plt.legend()
plt.show()


# So, the fitting function is t_final_mergertime = (10**50.19) * (j0**0.465)
# Out:
# Slope and intercept of fitting function = [ 0.46493149 50.19070741]

# %%
j0_array_3 = np.geomspace(1e-6, 1e-4, 10)

j0_ref_list_3 = j0_array_3.tolist()

def t_final_merger(j0):
    return  (10**45.39) * (j0**0.465)
    
tm_ref_list_3 = np.zeros(len(j0_ref_list_3))

for i, j0 in enumerate(j0_ref_list_3):
    tm_ref_list_3[i] = t_final_merger(j0)
    

    
    
np.savez("tmofjo_3_Lgnml_1",  j0_ref_list_3,  tm_ref_list_3)
plt.loglog(j0_ref_list_3, tm_ref_list_3, 'g')
plt.xlabel('$j_{i}$')
plt.ylabel('final merger time/yr')
plt.show()


print("j0_lower_values =", j0_ref_list_3)
print('\v')
print("final merger time / yr =", tm_ref_list_3)


file = np.load('tmofjo_1_Lgnml_2.npz')
ji_ref_list_1 = file['arr_0']
tm_ref_list_1 = file['arr_1']


file = np.load('tmofjo_2_Lgnml_2.npz')
ji_ref_list_2 = file['arr_0']
tm_ref_list_2 = file['arr_1']



j_initial_list = j0_ref_list_1 + j0_ref_list_2 + j0_ref_list_3


t_1 =  np.append(tm_ref_list_1, tm_ref_list_2) 

t_final_list = np.append(t_1, tm_ref_list_3 )

a_initial = 2.8541e+17   # in units of pc


a_i_ref_Lgnml_2 = a_initial 

np.savez("tm_ofj0_Lgnml_2", a_i_ref_Lgnml_2, j_initial_list,  t_final_list)
# Out:
# j0_lower_values = [1e-06, 1.6681005372000591e-06, 2.782559402207126e-06, 4.641588833612782e-06, 7.742636826811277e-06, 1.2915496650148827e-05, 2.1544346900318823e-05, 3.5938136638046256e-05, 5.994842503189409e-05, 0.0001]
#
# final merger time / yr = [3.98107171e+42 5.05048788e+42 6.40717619e+42 8.12830516e+42
#  1.03117727e+43 1.30817747e+43 1.65958691e+43 2.10539377e+43
#  2.67095559e+43 3.38844156e+43]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from matplotlib.pyplot import figure
import math


#Plot of the integrand of eq.(14) in the notes "time of merger" with and without the exponential factor 
#using using values of B and D for a binary with mass M_1PBH=5M☉, M_2PBH=5M☉   .

π=np.pi

B_list = [3.0672e-14] # B_min
D_list = [1.0488e+00] # D_min
h_list = [2.6837e+20] # h_min
 


def gamma(Y,D):      #eq.(12) in the notes.
    return ((((1+(0.1709*D*(Y**(-21/37))))**(-1/14))/(1+(0.0136*D*(Y**(-21/37)))))*Y)

def integrand(Y,B,D):        # Integrand of eq.(14) in the notes.
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37))*math.exp(-h*((Y/B)**(-21/37))))

f2 = np.vectorize(integrand)
       

    
def Integrand(Y,D):        #Integrand of eq.(14) without the exponential factor
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37)))



Y=np.linspace(0.0001,100,10000) 
fig, ax = plt.subplots( sharex=True, figsize=(10,5))

for (h,B,D) in (zip(h_list,B_list,D_list)):
    ax.loglog(Y,f2(Y,B,D))

for (B,D) in (zip(B_list,D_list)):
    ax.loglog(Y,Integrand(Y,D))




plt.rc('lines', linewidth=2.7)    
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(["$B_{min}\hspace{0.1},\hspace{0.1}D_{min}\hspace{0.5}with \hspace{0.3}exp-factor$ ",
            "$B_{min}\hspace{0.1},\hspace{0.1}D_{min} \hspace{0.3}without \hspace{0.4} exp-factor$"
            ],
           prop = {'size' :13},loc='lower left',shadow = True, facecolor = 'white',fontsize=19)
plt.xlabel('$y$',fontsize=12)
plt.ylabel('$Integrand$',fontsize=12)
plt.title('For a binary with mass M_1PBH=5M☉ and M_2PBH=5M☉')
plt.show()

# %%
#Plot of the integrand of eq.(14) in the notes "time of merger" with and without the exponential factor
#using using values of B and D for a binary with mass M_1PBH=50M☉, M_2PBH=50M☉   .

h_list = [7.8597e+20] # h_max
B_list = [1.9984e-09]  # B_max
D_list= [1.4221e+00]   # D_max



def gamma(Y,D):      #eq.(12) in the notes.
    return ((((1+(0.1709*D*(Y**(-21/37))))**(-1/14))/(1+(0.0136*D*(Y**(-21/37)))))*Y)

def integrand(Y,B,D):        #Integrand of eq.(14) in the notes.
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37))*math.exp(-h*((Y/B)**(-21/37))))

f2 = np.vectorize(integrand)
       

    
def Integrand(Y,D):        #Integrand of eq.(14) without the exponential factor
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37)))



Y=np.linspace(0.0001,100,10000) 
fig, ax = plt.subplots( sharex=True, figsize=(10,5))

for (h,B,D) in (zip(h_list,B_list,D_list)):
    ax.loglog(Y,f2(Y,B,D))

for (B,D) in (zip(B_list,D_list)):
    ax.loglog(Y,Integrand(Y,D))




plt.rc('lines', linewidth=2.4)    
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(["$B_{max}\hspace{0.1},\hspace{0.1}D_{min}\hspace{0.5}with \hspace{0.3}exp-factor$ ",
            "$B_{max}\hspace{0.1},\hspace{0.1}D_{min} \hspace{0.3}without \hspace{0.4} exp-factor$"
            ],
           prop = {'size' :13},loc='lower left',shadow = True, facecolor = 'white',fontsize=19)
plt.xlabel('$y$',fontsize=12)
plt.ylabel('$Integrand$',fontsize=12)
plt.title('For a binary with mass M_1PBH=50M☉ and M_2PBH=50M☉')
plt.show()

# %%
#Plot of the integrand of eq.(14) in the notes "time of merger" with and without the exponential factor
#using using values of B and D for a binary with mass M_1PBH=5M☉, M_2PBH=95M☉   .

h_list = [7.0111e+20] # h_max
B_list = [2.8836e-09]  # B_max
D_list= [1.2429e+00]   # D_max


def gamma(Y,D):      #eq.(12) in the notes.
    return ((((1+(0.1709*D*(Y**(-21/37))))**(-1/14))/(1+(0.0136*D*(Y**(-21/37)))))*Y)

def integrand(Y,B,D):        #Integrand of eq.(14) in the notes.
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37))*math.exp(-h*((Y/B)**(-21/37))))

f2 = np.vectorize(integrand)
       

    
def Integrand(Y,D):        #Integrand of eq.(14) without the exponential factor
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37)))



Y=np.linspace(0.0001,100,10000) 
fig, ax = plt.subplots( sharex=True, figsize=(10,5))

for (h,B,D) in (zip(h_list,B_list,D_list)):
    ax.loglog(Y,f2(Y,B,D))

for (B,D) in (zip(B_list,D_list)):
    ax.loglog(Y,Integrand(Y,D))




plt.rc('lines', linewidth=2.4)    
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(["$B_{max}\hspace{0.1},\hspace{0.1}D_{min}\hspace{0.5}with \hspace{0.3}exp-factor$ ",
            "$B_{max}\hspace{0.1},\hspace{0.1}D_{min} \hspace{0.3}without \hspace{0.4} exp-factor$"
            ],
           prop = {'size' :13},loc='lower left',shadow = True, facecolor = 'white',fontsize=19)
plt.xlabel('$y$',fontsize=12)
plt.ylabel('$Integrand$',fontsize=12)
plt.title('For a binary with mass M_1PBH=5M☉ and M_2PBH=95M☉')
plt.show()

# %%
#Plot of the integrand of eq.(14) in the notes "time of merger" with and without the exponential factor
#using using values of B and D for a binary with mass M_1PBH=1e-3M☉, M_2PBH=1e4M☉   .

h_list = [4.3532e+23]   # h_max
B_list = [6.5949e-04]   # B_max
D_list = [8.0248e-01]   # D_max


def gamma(Y,D):      #eq.(12) in the notes.
    return ((((1+(0.1709*D*(Y**(-21/37))))**(-1/14))/(1+(0.0136*D*(Y**(-21/37)))))*Y)

def integrand(Y,B,D):        #Integrand of eq.(14) in the notes.
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37))*math.exp(-h*((Y/B)**(-21/37))))

f2 = np.vectorize(integrand)
       

    
def Integrand(Y,D):        #Integrand of eq.(14) without the exponential factor
    return ((gamma(Y,D)**2)/(((gamma(Y,D)**2)+1)**(3/2))*(Y**(-58/37)))



Y=np.linspace(0.0001,100,10000) 
fig, ax = plt.subplots( sharex=True, figsize=(10,5))

for (h,B,D) in (zip(h_list,B_list,D_list)):
    ax.loglog(Y,f2(Y,B,D))

for (B,D) in (zip(B_list,D_list)):
    ax.loglog(Y,Integrand(Y,D))




plt.rc('lines', linewidth=2.4)    
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(["$B_{max}\hspace{0.1},\hspace{0.1}D_{min}\hspace{0.5}with \hspace{0.3}exp-factor$ ",
            "$B_{max}\hspace{0.1},\hspace{0.1}D_{min} \hspace{0.3}without \hspace{0.4} exp-factor$"
            ],
           prop = {'size' :13},loc='lower left',shadow = True, facecolor = 'white',fontsize=19)
plt.xlabel('$y$',fontsize=12)
plt.ylabel('$Integrand$',fontsize=12)
plt.title('For a binary with mass M_1PBH=$10^{-3}$M☉ and M_2PBH=$10^{4}$M☉')
plt.show()

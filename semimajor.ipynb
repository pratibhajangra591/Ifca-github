# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def f(u,b):
    return [u[1], -((u[0]*(b**2))/(λ*((u[0]**2+a**2)**(3/2))))] # with 2nd part of the eq.(9)
X0= [0.00001,1]
λ=1 # Here if I am using λ much less than 1, some numerical error is coming. 

a=1e-2 # Also, If I am using some positive value of a then straight line behaviour is coming.

bs= np.linspace(0.00001,2.0,400)# this range I fixed after hit and trial and taking hint from the paper.

us= odeint(f,X0,bs)
Xs= us[:,0]
As=bs/λ
Bs=Xs/λ
plt.plot(As,Bs,'r')
plt.xlabel('b/λ')
plt.ylabel('X/λ')
plt.title(' ')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(λ*((u[0]**2+b**2)**(3/2))))]
separation0= [1e-5,1]
λ=1
b=0.5e-2
ss= np.linspace(1e-5,2,90) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ
plt.plot(As,Bs,'r')
plt.xlabel('s/λ')
plt.ylabel('X/λ')
plt.title(' ')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(λ*((u[0]**2+b**2)**(3/2))))]
separation0= [1e-4,1]
λ=0.999
b=0.5e-2
ss= np.linspace(1e-4,2,90) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ
plt.plot(As,Bs,'r')
plt.xlabel('s/λ')
plt.ylabel('X/λ')
plt.title(' ')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(λ*((u[0]**2+b**2)**(3/2))))]
separation0= [1e-6,1]
λ=0.009
b=1e-2
ss= np.linspace(1e-6,2,1800) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ
plt.plot(As,Bs,'r')
plt.xlabel('s/λ')
plt.ylabel('X/λ')
plt.title(' ')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint



def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(λ*((u[0]**2+b**2)**(3/2))))]
separation0= [1e-5,1]
λ=1
b=1e-2
ss= np.linspace(1e-5,2,1000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ



def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(λ*((n[0]**2+c**2)**(3/2))))]
Z0= [1e-5,1]
λ=1
c=1e-3
ps= np.linspace(1e-5,2,1000) 
ns= odeint(j,Z0,ps)
Zs= ns[:,0]

def g(v,t):
    return [v[1], ((t*v[1]-v[0])/(t**2))-((v[0]*(t**2))/(λ*((v[0]**2+d**2)**(3/2))))]
λ=1
d= 1e-4
x0= [1e-5,1]
ts= np.linspace(1e-5,2,1000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]



def h(m,k):
    return [m[1],((k*m[1]-m[0])/(k**2))-((m[0]*(k**2))/(λ*((m[0]**2+e**2)**(3/2)))) ]
λ=1
e= 1e-5
y0= [1e-5,1]
ks= np.linspace(1e-5,2,1000) 
ms= odeint(h,y0,ks)
ys= ms[:,0]



plt.figure(figsize=(18, 11))

plt.plot(As,Bs,'r')
plt.plot(ps,Zs,'b')
plt.plot(ts,xs,'g')
plt.plot(ks,ys,'k')

plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["b=1e-2","b=1e-3","b=1e-4","b=1e-5"])     
plt.show()

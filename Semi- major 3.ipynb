# %%
#h(s)= math.sqrt((s**-2)+(s**-4))
#h'(s)= -((3*s+4)/(2*h(s)*(s**5)))
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint
def h(s):
    return math.sqrt((s**-3)+(s**-4))
def g(s):
        return  -((3*s+4)/(2*h(s)*(s**5)))   #g(s)=h'(s).

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*λ*((u[0]**2+b**2)**(3/2))))]
λ=1
b=1e-5
separation0= [1e-12,1]
ss= np.linspace(1e-12,2,1000000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ
plt.plot(As,Bs,'r')
plt.xlabel('s/λ')
plt.ylabel('X/λ')
plt.title(' ')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint

def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5))) #g(x)=h'(x).
    
    

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*λ*((u[0]**2+b**2)**(3/2))))]
λ=1
b=1e-2
separation0= [1e-10,1]
ss= np.linspace(1e-10,2,10000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ


def j(n,p):
    return [n[1], -((p*g(p)+h(p))*((p*n[1]-n[0]))/(h(p)*p**2))-((n[0])/((((h(p)*p)**2))*λ*((n[0]**2+b**2)**(3/2))))]
Z0= [1e-10,1]
λ=1
c=1e-3
ps= np.linspace(1e-10,2,10000) 
ns= odeint(j,Z0,ps)
Zs= ns[:,0]



def w(v,t):
    return [v[1], -((t*g(t)+h(t))*((t*v[1]-v[0]))/(h(t)*t**2))-((v[0])/((((h(t)*t)**2))*λ*((v[0]**2+d**2)**(3/2))))]
λ=1
d= 1e-4
x0= [1e-10,1]
ts= np.linspace(1e-10,2,10000) 
vs= odeint(w,x0,ts)
xs= vs[:,0]



def i(m,k):
    return [m[1],-((k*g(k)+h(k))*((k*m[1]-m[0]))/(h(k)*k**2))-((m[0])/((((h(k)*k)**2))*λ*((m[0]**2+e**2)**(3/2)))) ]
λ=1
e= 1e-5
y0= [1e-10,1]
ks= np.linspace(1e-10,2,1000000) 
ms= odeint(i,y0,ks)
ys= ms[:,0]



def a(l,o):
    return [l[1],-((o*g(o)+h(o))*((o*l[1]-l[0]))/(h(o)*o**2))-((l[0])/((((h(o)*o)**2))*λ*((l[0]**2+r**2)**(3/2)))) ]
λ=1
r= 1e-6
Y0= [1e-10,1]
os= np.linspace(1e-10,2,1000000) 
ls= odeint(a,Y0,os)
Ys= ls[:,0]

plt.figure(figsize=(18, 11))

plt.plot(As,Bs,'k')
plt.plot(ps,Zs,'b')
plt.plot(ts,xs,'g')
plt.plot(ks,ys,'r')
plt.plot(os,Ys, 'm')

plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["b=1e-2","b=1e-3","b=1e-4","b=1e-5","b=1e-6"])  
plt.title('Graph for the solution of eq.(6) with λ=1 using different impact parameters')  # E.(6) of paper 'The merger rate of primordial-black-hole binaries'.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint



def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(λ*((u[0]**2+b**2)**(3/2))))]
separation0= [1e-12,1]
λ=0.009
b=1e-4
ss= np.linspace(1e-12,1e-2,6000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ



def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(λ*((n[0]**2+c**2)**(3/2))))]
z0= [1e-12,1]
λ=0.009
c=1e-5
ps= np.linspace(1e-12,1e-2,6000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ
Zs=zs/λ

def g(v,t):
    return [v[1], ((t*v[1]-v[0])/(t**2))-((v[0]*(t**2))/(λ*((v[0]**2+d**2)**(3/2))))]
λ=0.009
d= 1e-6
x0= [1e-12,1]
ts= np.linspace(1e-12,1e-2,6000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]
Ts=ts/λ
Xs=xs/λ


def h(m,k):
    return [m[1],((k*m[1]-m[0])/(k**2))-((m[0]*(k**2))/(λ*((m[0]**2+e**2)**(3/2)))) ]
λ=0.009
e= 1e-7                                      
    
y0= [1e-12,1]
ks= np.linspace(1e-12,1e-2,6000) 
ms= odeint(h,y0,ks)
ys= ms[:,0]
Ks=ks/λ
Ys=ys/λ



plt.figure(figsize=(18, 12))

plt.plot(As,Bs,'b--')
plt.plot(Ps,Zs,'m')
plt.plot(Ts,Xs,'r')
plt.plot(Ks,Ys,'g')

plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["b=1e-4","b=1e-5","b=1e-6","b=1e-7"]) 
plt.title('Graph for the solution of eq.(9) with λ=0.009 using different impact parameters') # E.(9) of paper 'The merger rate of primordial-black-hole binaries'.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint

def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5)))
    
    

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*λ*((u[0]**2+b**2)**(3/2))))]
λ=1
b=1e-4
separation0= [1e-10,1]
ss= np.linspace(1e-10,2,10000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ


def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(λ*((n[0]**2+c**2)**(3/2))))]
z0= [1e-12,1]
λ=0.009
c=1e-5
ps= np.linspace(1e-12,1e-2,6000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ
Zs=zs/λ



plt.figure(figsize=(18, 12))

plt.plot(As,Bs,'k--')
plt.plot(Ps,Zs,'k')

plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["b=1e-4 & λ=1","b=1e-5 & λ=0.009"]) 
plt.title('solution of eq.(9) using λ=0.009 and solution of eq.(6) using λ=1 ') # Reference paper "The merger rate of primordial-black-hole binaries".
plt.show()

# %%
# task no. 1 Solve (numerically) for the evolution of an equal-mass PBH binary, 
#with a time-dependent DM halo 

import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.integrate import odeint

def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5))) #g(x)=h'(x).
rho_eq=1.3911e-16
t_eq=1.997e8
pi=3.14

def n(s):
    return (1+((((64*pi*rho_eq*(t_eq**2))/3)**(3/4))*(((((2*(s-2)*((s+1)**(1/2)))/3)+(4/3))**(1/2)))))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*2*λ(s)*((u[0]**2
                                                                                    +b**2)**(3/2))))]
λ_0=1
b=1e-6
separation0= [1e-12,1]
ss= np.linspace(1e-12,5e-1,10000000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ_0
Bs=separations/λ_0

plt.figure(figsize=(16, 8))

plt.plot(As,Bs,'r')
plt.xlabel('s/λ_0')
plt.ylabel('X/λ_0')
plt.title('Graph for the solution of eq.(74) with λ_0=1 using different impact parameters') 
plt.show()

# %%
def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5))) #g(x)=h'(x).

rho_eq=1.3911e-16
t_eq=1.997e8

def n(s):
    return (1+((((64*3.14*rho_eq*(t_eq**2))/3)**(3/4))*(((((2*(s-2)*((s+1)**(1/2)))/3)+(4/3))**(1/2)))))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*2*λ(s)*((u[0]**2
                                                                                    +b**2)**(3/2))))]
λ_0=1
b=1e-4
separation0= [1e-12,1]
ss= np.linspace(1e-12,5e-1,10000000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss
Bs=separations




def w(v,t):
    return [v[1], -((t*g(t)+h(t))*((t*v[1]-v[0]))/(h(t)*t**2))-((v[0])/((((h(t)*t)**2))*2*λ(t)*((v[0]**2+d**2)**(3/2))))]
λ_0=1
d= 1e-5
x0= [1e-12,1]
ts= np.linspace(1e-12,5e-1,10000) 
vs= odeint(w,x0,ts)
xs= vs[:,0]



def i(m,k):
    return [m[1],-((k*g(k)+h(k))*((k*m[1]-m[0]))/(h(k)*k**2))-((m[0])/((((h(k)*k)**2))*2*λ(k)*((m[0]**2+e**2)**(3/2)))) ]
λ_0=1
e= 1e-6
y0= [1e-12,1]
ks= np.linspace(1e-12,5e-1,1000000) 
ms= odeint(i,y0,ks)
ys= ms[:,0]



def a(l,o):
    return [l[1],-((o*g(o)+h(o))*((o*l[1]-l[0]))/(h(o)*o**2))-((l[0])/((((h(o)*o)**2))*2*λ(o)*((l[0]**2+r**2)**(3/2)))) ]
λ_0=1
r= 1e-7
Y0= [1e-12,1]
os= np.linspace(1e-12,5e-1,1000000) 
ls= odeint(a,Y0,os)
Ys= ls[:,0]

plt.figure(figsize=(16, 8))

plt.plot(As,Bs,'k')
plt.plot(ts,xs,'m')
plt.plot(ks,ys,'g')
plt.plot(os,Ys, 'r')

plt.xlabel('s/λ_0')
plt.ylabel('X/λ_0')  
plt.legend(["b=1e-2","b=1e-3","b=1e-4","b=1e-5","b=1e-6"])  
plt.title('Graph for the solution of eq.(74) with λ_0=1 using different impact parameters') 
plt.show()

# %%
def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5))) #g(x)=h'(x).

rho_eq=1.3911e-16
t_eq=1.997e8
pi=3.14

def n(s):
    return (1+(((8*pi*rho_eq*(t_eq**2))/3)**(3/4))*(2**(7/4)*s))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)

def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(2*λ(s)*((u[0]**2+b**2)**(3/2))))]
λ_0=0.009
b=1e-3
separation0= [1e-12,1]
ss= np.linspace(1e-12,4e-2,1000000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ_0
Bs=separations/λ_0

plt.figure(figsize=(16, 8))

plt.plot(As,Bs,'r')
plt.xlabel('s/λ_0')
plt.ylabel('X/λ_0')
plt.title('Graph for the solution of eq.(78) with λ_0=0.009') 
plt.show()

# %%
rho_eq=1.3911e-16
t_eq=1.997e8
pi=3.14

def n(s):
    return (1+(((8*pi*rho_eq*(t_eq**2))/3)**(3/4))*(2**(7/4)*s))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)

def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(2*λ(s)*((u[0]**2+b**2)**(3/2))))]
λ_0=0.009
b=1e-4
separation0= [1e-12,1]
ss= np.linspace(1e-12,2e-2,1000000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ_0
Bs=separations/λ_0

def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(2*λ(p)*((n[0]**2+c**2)**(3/2))))]
z0= [1e-12,1]
λ_0=0.009
c=1e-5
ps= np.linspace(1e-12,2e-2,1000000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ_0
Zs=zs/λ_0

def g(v,t):
    return [v[1], ((t*v[1]-v[0])/(t**2))-((v[0]*(t**2))/(2*λ(t)*((v[0]**2+d**2)**(3/2))))]
λ_0=0.009
d= 1e-6
x0= [1e-12,1]
ts= np.linspace(1e-12,2e-2,1000000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]
Ts=ts/λ_0
Xs=xs/λ_0


def h(m,k):
    return [m[1],((k*m[1]-m[0])/(k**2))-((m[0]*(k**2))/(2*λ(k)*((m[0]**2+e**2)**(3/2)))) ]
λ_0=0.009
e= 1e-7                                          
y0= [1e-12,1]
ks= np.linspace(1e-12,2e-2,1000000) 
ms= odeint(h,y0,ks)
ys= ms[:,0]
Ks=ks/λ_0
Ys=ys/λ_0



plt.figure(figsize=(16, 8))

plt.plot(As,Bs,'r')
plt.plot(Ps,Zs,'g')
plt.plot(Ts,Xs,'b')
plt.plot(Ks,Ys,'k')

plt.xlabel('s/λ_0')
plt.ylabel('X/λ_0')  
plt.legend(["b=1e-4","b=1e-5","b=1e-6","b=1e-7"]) 
plt.title('Graph for the solution of eq.(78) for λ_0=0.009 using different impact parameters') 
plt.show()

# %%
def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5))) #g(x)=h'(x).

rho_eq=1.3911e-16
t_eq=1.997e8

def n(s):
    return (1+((((64*3.14*rho_eq*(t_eq**2))/3)**(3/4))*(((((2*(s-2)*((s+1)**(1/2)))/3)+(4/3))**(1/2)))))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_00*k(s)

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*2*λ(s)*((u[0]**2
                                                                                    +b**2)**(3/2))))]
λ_00=1
b=1e-4
separation0= [1e-12,1]
ss= np.linspace(1e-12,1,100000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss
Bs=separations


def m(s):
    return (1+(((8*3.14*rho_eq*(t_eq**2))/3)**(3/4))*(2**(7/4)*s))

def  g(s):
    return (1/m(s))

def λ_(s):
    return λ_0*g(s)


def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(2*λ_(p)*((n[0]**2+c**2)**(3/2))))]
z0= [1e-12,1]
λ_0=0.009
c=1e-6
ps= np.linspace(1e-12,3e-2,100000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ_0
Zs=zs/λ_0

plt.figure(figsize=(16, 8))

plt.plot(As, Bs, 'b')
plt.plot(Ps,Zs,'g')


plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["eq.(74) using λ_0=1 ", "eq.(78) using λ_0=0.009"]) 
plt.title('') 
plt.show()

# %%
# Task no. 2 Compare this solution (including a time dependent DM halo) with 
#the original case (with no DM halo)


def h(x):
    return math.sqrt((x**-3)+(x**-4))
def g(x):
        return  -((3*x+4)/(2*h(x)*(x**5)))
    
    

def f(u,s):
    return [u[1], -((s*g(s)+h(s))*((s*u[1]-u[0]))/(h(s)*s**2))-((u[0])/((((h(s)*s)**2))*λ*((u[0]**2+b**2)
                          **(3/2))))] #eq. of binary having equal masses of PBHs without DM halos

λ=1
b=1e-4
separation0= [1e-10,1]
ss= np.linspace(1e-10,1.8,10000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ


rho_eq=1.3911e-16
t_eq=1.997e8

def n(s):
    return (1+((((64*3.14*rho_eq*(t_eq**2))/3)**(3/4))*(((((2*(s-2)*((s+1)**(1/2)))/3)+(4/3))**(1/2)))))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)


def w(v,t):
    return [v[1], -((t*g(t)+h(t))*((t*v[1]-v[0]))/(h(t)*t**2))-((v[0])/((((h(t)*t)**2))*2*λ(t)
                     *((v[0]**2+d**2)**(3/2))))] #eq. of binary having equal masses of PBHs with DM halos     
λ_0=1
d= 1e-3
x0= [1e-10,1]
ts= np.linspace(1e-10,7e-1,1000000) 
vs= odeint(w,x0,ts)
xs= vs[:,0]
Ts=ts/λ_0
Xs=xs/λ_0




plt.figure(figsize=(18, 10))

plt.plot(As,Bs,'k')
plt.plot(Ts,Xs,'k--')

plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["b=1e-4 & λ=1 for binary without DM halos","b=1e-3 & λ=0.009 for binary having DM halos"]) 
plt.title('comparison graph for PBH-binary with and without DM halos') 
plt.show()

# %%
#Comparison of the eqs. of binary in radiation domination case:-


def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(λ*((n[0]**2+c**2)**(3/2))))]
                   # eq. of binary with equal masses without DM halos

z0= [1e-12,1]
λ=0.009
c=1e-6
ps= np.linspace(1e-12,2.4e-2,100000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ
Zs=zs/λ



rho_eq=1.3911e-16
t_eq=1.997e8
pi=3.14

def n(s):
    return (1+(((8*pi*rho_eq*(t_eq**2))/3)**(3/4))*(2**(7/4)*s))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)

def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(2*λ(s)*((u[0]**2+b**2)**(3/2))))]
                  #eq. of binary with equal masses with DM halos
    
λ_0=0.009
b=1e-6
separation0= [1e-12,1]
ss= np.linspace(1e-12,2.4e-2,1000000) 
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ_0
Bs=separations/λ_0





plt.figure(figsize=(18, 10))

plt.plot(Ps,Zs,'k')
plt.plot(As,Bs,'k--')


plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["b=1e-6 & λ=1 for binary without DM halos","b=1e-6 & λ=0.009 for binary having DM halos"]) 
plt.title('comparison graph for PBH-binary with and without DM halos in radiation domination') 
plt.show()

# %%
#Task no. 4 For the case of PBH binaries without DM, check the relation between the semi-major axis a 
#and the comoving separation x, which is given in Eq. (11) of https://arxiv.org/abs/1709.06576. 



import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.integrate import odeint



def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(λ*((u[0]**2+b**2)**(3/2))))]
separation0= [1e-12,1]
λ=0.0009
b=1e-6
ss= np.linspace(1e-12,3e-3,3000)  
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ
Bs=separations/λ

def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(λ*((n[0]**2+c**2)**(3/2))))]
z0= [1e-12,1]
λ=0.001
c=1e-6
ps= np.linspace(1e-12,3e-3,3000)
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ
Zs=zs/λ

def g(v,t):
    return [v[1], ((t*v[1]-v[0])/(t**2))-((v[0]*(t**2))/(λ*((v[0]**2+d**2)**(3/2))))]
λ=0.003
d= 1e-6
x0= [1e-12,1]
ts= np.linspace(1e-12,1e-2,2500) 
vs= odeint(g,x0,ts)
xs= vs[:,0]
Ts=ts/λ
Xs=xs/λ

def h(m,k):
    return [m[1],((k*m[1]-m[0])/(k**2))-((m[0]*(k**2))/(λ*((m[0]**2+e**2)**(3/2)))) ]
λ=0.009
e= 1e-6                                         
y0= [1e-12,1]
ks= np.linspace(1e-12,2e-2,3000)
ms= odeint(h,y0,ks)
ys= ms[:,0]
Ks=ks/λ
Ys=ys/λ



plt.figure(figsize=(18, 9))

plt.plot(As,Bs,'k')
plt.plot(Ps,Zs,'r')
plt.plot(Ts,Xs,'b')
plt.plot(Ks,Ys,'g')

plt.xlabel('s/λ')
plt.ylabel('X/λ')  
plt.legend(["λ=0.0009","λ=0.001","λ=0.003","λ=0.009"]) 
plt.title('Graph for the solution of eq.(9) with b=1e6 using different λ-parameters ')
# E.(9) of paper 'The merger rate of primordial-black-hole binaries'.
plt.show()

# %%
# Task no. 5 How does this relation change when we include the (time-dependent) DM halo?


rho_eq=1.3911e-16
t_eq=1.997e8
pi=3.14

def n(s):
    return (1+(((8*pi*rho_eq*(t_eq**2))/3)**(3/4))*(2**(7/4)*s))

def  k(s):
    return (1/n(s))

def λ(s):
    return λ_0*k(s)

def f(u,s):
    return [u[1], ((s*u[1]-u[0])/(s**2))-((u[0]*(s**2))/(2*λ(s)*((u[0]**2+b**2)**(3/2))))]
λ_0=0.0009
b=1e-6
separation0= [1e-12,1]
ss= np.linspace(1e-12,4e-3,8000)
us= odeint(f,separation0,ss)
separations= us[:,0]
As=ss/λ_0
Bs=separations/λ_0

def j(n,p):
    return [n[1], ((p*n[1]-n[0])/(p**2))-((n[0]*(p**2))/(2*λ(p)*((n[0]**2+c**2)**(3/2))))]
z0= [1e-12,1]
λ_0=0.001
c=1e-6
ps= np.linspace(1e-12,4e-3,8000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
Ps=ps/λ_0
Zs=zs/λ_0

def g(v,t):
    return [v[1], ((t*v[1]-v[0])/(t**2))-((v[0]*(t**2))/(2*λ(t)*((v[0]**2+d**2)**(3/2))))]
λ_0=0.003
d= 1e-6
x0= [1e-12,1]
ts= np.linspace(1e-12,8e-3,8000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]
Ts=ts/λ_0
Xs=xs/λ_0


def h(m,k):
    return [m[1],((k*m[1]-m[0])/(k**2))-((m[0]*(k**2))/(2*λ(k)*((m[0]**2+e**2)**(3/2)))) ]
λ_0=0.009
e= 1e-6                                          
y0= [1e-12,1]
ks= np.linspace(1e-12,3e-2,40000)
ms= odeint(h,y0,ks)
ys= ms[:,0]
Ks=ks/λ_0
Ys=ys/λ_0



plt.figure(figsize=(16, 8))

plt.plot(As,Bs,'r')
plt.plot(Ps,Zs,'g')
plt.plot(Ts,Xs,'b')
plt.plot(Ks,Ys,'k')

plt.xlabel('s/λ_0')
plt.ylabel('X/λ_0')  
plt.legend(["λ=0.0009","λ=0.001","λ=0.003","λ=0.009"]) 
plt.title('Graph for the solution of eq.(78) for with b=1e6 using different λ-parameters ') 
plt.show()

# %%
# Task no. 7 The evolution of the radius of DM shells around a PBH as a function of time, 
#for different values of the initial radius of the shell (we talked about doing this to 
#demonstrate the different regimes: immediate in-fall, turn around and non-stop expansion)
G= 6.67e-11
M= 1.989e32

def j(n,p):
    return [n[1], (((-G*M)/((n[0]**2))) - (n[0]/(4*p**2)))]

z0= [1e10,2.12044e4]   #with initial distance r_i=1e10m

ps= np.linspace(2.358e5,2.4e5,2000000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
plt.plot(ps,zs,'r')
plt.xlabel('t in seconds')
plt.ylabel('r in meters')
plt.title('using initial distance r_i=1e10m')
plt.show()

# %%
def f(u,w):
    return [u[1], (((-G*M)/((u[0]**2))) - (u[0]/(4*w**2)))]

r0= [1e11,2.12044e5]   #with initial distance r=1e11m

ws= np.linspace(2.358e5,6e5,200000)
us= odeint(f,r0,ws)
rs= us[:,0]
plt.plot(ws,rs,'r')
plt.xlabel('t in seconds')
plt.ylabel('r in meters')  
plt.title('using initial distance r_i=1e11m')
plt.show()

# %%
def h(m,k):
    return [m[1], (((-G*M)/((m[0]**2))) - (m[0]/(4*k**2)))]  

y0= [1e12,2.12044e6]  #with initial distance r_i=1e12m

ks= np.linspace(2.358e5,8.5e9,50000)
ms= odeint(h,y0,ks)
ys= ms[:,0]

plt.plot(ks,ys,'r')

plt.xlabel('t in seconds')
plt.ylabel('r in meters')  
plt.title('using initial distance r_i=1e12m')    
plt.show()

# %%
def g(v,t):
    return [v[1], (((-G*M)/((v[0]**2))) - (v[0]/(4*t**2)))]

x0= [1e13,2.12044e7]   #with initial distance r_i=1e13m


ts= np.linspace(2.358e5,7.7e15,2000000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]


plt.plot(ts,xs,'r')


plt.xlabel('t in seconds')
plt.ylabel('r in meters')  
plt.title('using initial distance r_i=1e13m')    
plt.show()

# %%
def g(v,t):
    return [v[1], (((-G*M)/((v[0]**2))) - (v[0]/(4*t**2)))]

x0= [1e14,2.12044e8]   #with initial distance r_i=1e14m


ts= np.linspace(2.358e5,1e20,200000000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]


plt.plot(ts,xs,'r')


plt.xlabel('t in seconds')
plt.ylabel('r in meters')  
plt.title('using initial distance r_i=1e14m')    
plt.show()

# %%
def f(u,w):
    return [u[1], (((-G*M)/((u[0]**2))) - (u[0]/(4*w**2)))]
r0= [1e11,2.12044e5]
ws= np.linspace(2.358e5,6e5,200000)
us= odeint(f,r0,ws)
rs= us[:,0]


def h(m,k):
    return [m[1], (((-G*M)/((m[0]**2))) - (m[0]/(4*k**2)))]                                          
y0= [1e12,2.12044e6]
ks= np.linspace(2.358e5,8.5e9,50000)
ms= odeint(h,y0,ks)
ys= ms[:,0]

def g(v,t):
    return [v[1], (((-G*M)/((v[0]**2))) - (v[0]/(4*t**2)))]
x0= [1e13,2.12044e7]
ts= np.linspace(2.358e5,7.7e15,2000000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]

plt.figure(figsize=(10, 6))

plt.plot(ps,zs,'g')
plt.plot(ws,rs,'k')
plt.plot(ks,ys,'r')
plt.plot(ts,xs,'b')

plt.xlabel('t in seconds')
plt.ylabel('r in meters')  
plt.legend(["r=1e10m","r=1e11m","r=1e12m","r=1e13m"])    
plt.show()

# %%
# Task no.8 a.) A plot of the DM halo mass as a function of time.


pi=3.14
M_PBH=1.989e32
rho_eq=1.3911e-16
t_eq=1.997e8

#M(t)=((8/3)*pi*rho_eq*G*M_PBH*(2**(5/4))*(t_eq**(3/2))*(t**(1/2))))



t= np.linspace(2.358e5,1e15,200000)

plt.plot(t, ((8/3)*pi*rho_eq*G*M_PBH*(2**(5/4))*(t_eq**(3/2))*(t**(1/2))),'r')
plt.xlabel('M_DM in kg')
plt.ylabel('t in seconds')
plt.show()

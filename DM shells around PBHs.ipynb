# %%
# The evolution of the radius of DM shells around a PBH (of mass, M_PBH=100 solar mass) 
# as a function of time, for different values of the initial radius of the shell demonstrating
# the different regimes: immediate in-fall, turn around and non-stop expansion)

#Reference research paper "WIMPs and stellar-mass primordial black holes are incompatible".

# %matplotlib inline
import numpy as np
from scipy.integrate import odeint
import math
import matplotlib.pyplot as plt
from matplotlib import rcParams

plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})
 

π = np.pi
Ω_cdm = 0.85
G = 6.67e-11                # in units of m^3⋅kg^−1⋅s^−2
t_i = 2.358e5                # in units of seconds
t_eq = 1.5923e12            # in units of seconds
ρ_eq = 2.1548e-16          # in units of kg m^-3
M_solar = 1.989e30        # in units of kg

A = 1.495e11                 # Astronomical unit
pc = 3.085e16               # in unist of meter. 
yr = 3.154e7              # in units of seconds
a_eq = 2.9374e-4


def j(n,p):
    M_PBH = 100 * M_solar            # in units of solar mass.
    return [n[1], (((-G*M_PBH)/((n[0]**2))) - (n[0]/(4*p**2)))]

z0= [1e10,2.12044e4]   #with initial radius, r_i=1e10m

ps= np.linspace(2.358e5, 2.4e5, 2000000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
z_max= (np.max(zs))
p_max = ps[np.argmax(zs)]
print("r_ta=",'%.4e'%z_max,"m",",","t_ta=",'%.4e'% p_max,"s")



plt.figure(figsize=(12.5, 4.5))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)

plt.plot(ps,zs,'r')
plt.xlabel('$t \, $[s]',fontsize = 15.5)
plt.ylabel('$r \, $ [m]',fontsize = 15.5)
plt.title('Dynamics of a DM shell around a PBH of mass, $\mathrm{M_\mathrm{PBH}} = 100 \,  \mathrm{M_{\odot}}$ with initial radius, $r_{i}=10^{10}\,$m', fontsize = 15)
plt.show()
# Out:
# r_ta= 1.0002e+10 m , t_ta= 2.3596e+05 s

# %%
def f(u,w):
    M_PBH = 100 * M_solar
    return [u[1], (((-G*M_PBH)/((u[0]**2))) - (u[0]/(4*w**2)))]

r0= [1e11,2.12044e5]   #with initial radius, r_i=1e11m

ws= np.linspace(2.358e5,6e5,200000)
us= odeint(f,r0,ws)
rs= us[:,0]
r_max= (np.max(rs))
w_max = ws[np.argmax(rs)]
print("r_ta=",'%.4e'%r_max,"m",",","t_ta=",'%.4e'% w_max,"s")


plt.figure(figsize = (12.5, 4.5))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)

plt.plot(ws,rs,'r')
plt.xlabel('$t \, $[s]',fontsize = 17.5)
plt.ylabel('$r \, $ [m]',fontsize = 17.5)
plt.title('Dynamics of a DM shell around a PBH of mass, $\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}}$ with initial radius, $r_{i}=10^{11}\,$m', fontsize = 15)
plt.show()
# Out:
# r_ta= 1.1503e+11 m , t_ta= 3.8764e+05 s

# %%
def h(m,k):
    M_PBH = 100 * M_solar
    return [m[1], (((-G*M_PBH)/((m[0]**2))) - (m[0]/(4*k**2)))]  

y0= [1e12,2.12044e6]  #with initial radius, r_i=1e12m

ks= np.linspace(2.358e5,8.5e9,50000)
ms= odeint(h,y0,ks)
ys= ms[:,0]
y_max= (np.max(ys))
k_max = ks[np.argmax(ys)]


plt.figure(figsize = (12.5, 4.5))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

plt.plot(ks,ys,'r')
print("r_ta=",'%.4e'%y_max,"m",",","t_ta=",'%.4e'% k_max,"s")
plt.xlabel('$t \, $[s]',fontsize = 16.5)
plt.ylabel('$r \, $ [m]',fontsize = 16.5)
plt.title('Dynamics of a DM shell around a PBH of mass, $\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}}$  with initial radius, $r_{i}=10^{12}\,$m', fontsize = 15)
plt.show()
# Out:
# r_ta= 6.9786e+13 m , t_ta= 3.4368e+09 s

# %%
def g(v,t):
    M_PBH = 100 * M_solar
    return [v[1], (((-G*M_PBH)/((v[0]**2))) - (v[0]/(4*t**2)))]

x0= [1e13,2.12044e7]   #with initial radius r_i=1e13m

ts= np.linspace(2.358e5,7e15,2000000) 
vs= odeint(g,x0,ts)
xs= vs[:,0]
x_max= (np.max(xs))
t_max = ts[np.argmax(xs)]
print("r_ta=",'%.4e'%x_max,"m",",","t_ta=",'%.4e'% t_max,"s")


plt.figure(figsize=(12.5, 4.6))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)


plt.plot(ts,xs,'r')
plt.xlabel('$t \, $[s]',fontsize = 15.5)
plt.ylabel('$r \, $ [m]',fontsize = 15.5)
plt.title('Dynamics of a DM shell around a PBH of mass, $\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}}$ with initial radius, $r_{i}=10^{13}\,$m', fontsize = 15)
plt.show()
# Out:
# r_ta= 6.6012e+17 m , t_ta= 3.1568e+15 s

# %%
M_PBH = 100 * M_solar


# Analytical estimate of 
#  a.) turnaround radius of the DM shell at matter-radiation equlaity, t_eq=1.5924e12s.

r_ta = (4*G*M_PBH*(t_eq**2))**(1/3) 
# eq.(4) reference research paper "WIMPs and stellar-mass primordial black holes are incompatible"
print("r_ta =",'%.4e' % r_ta,"m")



#  b.) the initial  radius of the shell of DM halo which just truns around at the point of
#      matter-radiation equality i.e. t_eq=1.5924e12s.
#using the relation for the analytical estimate of the turnaround radius, r_ta from a given value of r_i 
# i.e. r_ta= (r_i^4)/(16*G*M_PBH*t_i^2)

r_i = (16*G*M_PBH*r_ta*(t_i**2))**(1/4)     
                                                
print("r_i =",'%.4e'% r_i,"m")
# Out:
# r_ta = 5.1242e+15 m
# r_i = 2.7887e+12 m

# %%
# Plot showing the dynamics of a shell of DM halo at an initial radius of r_i= 2.7887e+12 m
# from the PBH of mass, M_PBH=100 solar mass.

# (The aim is to check whether the shell of DM halo at initial radius of  r_i= 2.7887e+12 m turns 
#  around the PBH at matter-radiation equlaity,t_eq=1.59246e12s or not.)


def h(m,k):
    M_PBH = 100 * M_solar
    return [m[1], (((-G*M_PBH)/((m[0]**2))) - (m[0]/(4*k**2)))]  
r_i=2.7887e+12 
t_i=2.358e5 
y0= [r_i,(r_i/(2*t_i))]  

ks= np.linspace(2.358e5,3e12,50000)
ms= odeint(h,y0,ks)
ys= ms[:,0]
y_max= (np.max(ys))
k_max = ks[np.argmax(ys)]

print("r_ta=",'%.4e'%y_max,"m",",","t_ta=",'%.4e'% k_max,"s")

plt.figure(figsize=(16, 4.7))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 19)
plt.yticks(fontsize = 19)
plt.plot(ks,ys,'r')

plt.xlabel('$t \, $[s]',fontsize = 21.5)
plt.ylabel('$r \, $ [m]',fontsize = 21.5)
plt.title(r'Dynamics of a DM shell around a PBH of mass, $\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}}$ with initial radius, $r_{i} = 2.7887 \times 10^{12}\,$m', fontsize = 17.6)
plt.show()
# Out:
# r_ta= 4.0089e+15 m , t_ta= 1.4941e+12 s

# %%
# As the main aim is to find out about the shell of DM halo at given initial radius ,r_i from the PBH
# which just turns around the PBH at matter-radiation equlaity, t_eq=1.59246e12s so, I tried to play around
# the value of  analytically estimated value of r_i= 2.7887e+12m to find out which shell has the 
# turn around time closest to  matter-radiation equlaity, t_eq=1.59246e12s.

def h(m,k):
    M_PBH = 100 * M_solar
    return [m[1], (((-G*M_PBH)/((m[0]**2))) - (m[0]/(4*k**2)))]  
r_i=2.81856e+12 
t_i=2.358e5 
y0= [r_i,(r_i/(2*t_i))]  

ks= np.linspace(2.358e5,3e12,50000)
ms= odeint(h,y0,ks)
ys= ms[:,0]
y_max= (np.max(ys))
k_max = ks[np.argmax(ys)]

print("r_ta=",'%.4e'%y_max,"m",",","t_ta=",'%.4e'% k_max,"s")


plt.figure(figsize = (13, 4.5))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.plot(ks,ys,'r')

plt.xlabel('$t \, $[s]',fontsize = 17.5)
plt.ylabel('$r \, $ [m]',fontsize = 17.5)
plt.title(r'Dynamics of a DM shell around a PBH of mass, $\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}}$ with initial radius, $r_{i} = 2.81856 \times 10^{12}\,$m', fontsize = 13.5)
plt.show()
#The numerical value of the turn around time,t_ta for this shell is very close to t_eq.
# Out:
# r_ta= 4.1829e+15 m , t_ta= 1.5924e+12 s

# %%
# Dynamics of the various shells of DM halo around a PBH of mass, M_PBH=100 
# solar mass at different initial radii


M_PBH = 100 * M_solar

def j(n,p):
    return [n[1], (((-G*M_PBH)/((n[0]**2))) - (n[0]/(4*p**2)))]
z0= [1e10,2.12044e4]   #with initial distance r_i=1e10m
ps= np.linspace(2.358e5,2.4e5,2000000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]


def f(u,w):
    return [u[1], (((-G*M_PBH)/((u[0]**2))) - (u[0]/(4*w**2)))]
r0= [1e11,2.12044e5]        #with initial distance r_i=1e11m
ws= np.linspace(2.358e5,6e5,200000)
us= odeint(f,r0,ws)
rs= us[:,0]


def h(m,k):
    return [m[1], (((-G*M_PBH)/((m[0]**2))) - (m[0]/(4*k**2)))]                                          
y0= [1e12,2.12044e6]             #with initial distance r_i=1e12m
ks= np.linspace(2.358e5,8.5e9,50000)
ms= odeint(h,y0,ks)
ys= ms[:,0] 


def g(v,t):
    return [v[1], (((-G*M_PBH)/((v[0]**2))) - (v[0]/(4*t**2)))]
x0= [2.81856e+12 ,5.9766e+06]            #with initial distance r_i=1e2.81856e+12m
ts= np.linspace(2.358e5,1.5924e12,2000000) 
vs= odeint(g,x0,ts)
xs= vs[:,0] 

def r(t):
    return ((4*G*M_PBH*(t**(2)))**(1/3))
t= np.linspace(2.358e5,3e12,200000)

plt.figure(figsize=(9, 5.5))

plt.rc('lines', linewidth=1.3)
plt.xticks(fontsize = 23)
plt.yticks(fontsize = 23)


plt.loglog(ts,xs,'r')
plt.loglog(ks,ys,'b')
plt.loglog(ws,rs,'y')
plt.loglog(ps,zs,'g')
plt.loglog(t,r(t),'k--')

plt.xlabel('$t \, $[s]',fontsize= 18.5)
plt.ylabel('$r \, $ [m]',fontsize = 18.5) 
plt.legend([r"$r=2.81856\times 10^{12}\,m$","$r=10^{12}\,m$","$r=10^{11}\,m$","$r=10^{10}\,m$","$r_{turn\,around}$"], 
           prop = {'size':15}, facecolor = 'white',loc = 'lower right',shadow = True,fontsize = 100) 

plt.title('$\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}}$', fontsize = 19, pad = 9)
plt.show()

# %%
# Dynamics of the various shells of DM halo around a PBH of mass 100 M_solar  
# at different initial radii

M_PBH = 100 * M_solar

def j(n,p):
    return [n[1], (((-G*M_PBH)/((n[0]**2))) - (n[0]/(4*p**2)))]
z0= [1e10,2.12044e4]   #with initial distance r_i=1e10m
ps= np.linspace(2.358e5,2.4e5,2000000) 
ns= odeint(j,z0,ps)
zs= (ns[:,0])/1e10


def f(u,w):
    return [u[1], (((-G*M_PBH)/((u[0]**2))) - (u[0]/(4*w**2)))]
r0= [1e11,2.12044e5]        #with initial distance r_i=1e11m
ws= np.linspace(2.358e5,6e5,200000)
us= odeint(f,r0,ws)
rs= (us[:,0])/1e11


def h(m,k):
    return [m[1], (((-G*M_PBH)/((m[0]**2))) - (m[0]/(4*k**2)))]                                          
y0= [1e12,2.12044e6]             #with initial distance r_i=1e12m
ks= np.linspace(2.358e5,8.5e9,50000)
ms= odeint(h,y0,ks)
ys= (ms[:,0])/1e12


def g(v,t):
    return [v[1], (((-G*M_PBH)/((v[0]**2))) - (v[0]/(4*t**2)))]
x0= [2.81856e+12 ,5.9766e+06]            #with initial distance r_i=1e2.81856e+12m
ts= np.linspace(2.358e5,1.5924e12,2000000) 
vs= odeint(g,x0,ts)
xs= (vs[:,0])/2.81856e+12

def r(t):
    return ((4*G*M_PBH*(t**(2)))**(1/3))
t= np.linspace(2.358e5,3e12,200000)




plt.figure(figsize=(11, 5))
plt.rc('lines', linewidth=1.3)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)




plt.loglog(t,r(t),'k--')
plt.loglog(ts,xs,'r')
plt.loglog(ks,ys,'b')
plt.loglog(ws,rs,'k')

plt.loglog(ps,zs,'g')

plt.xlabel('$t \, $[s]',fontsize = 19.5)
plt.ylabel('$r/r_{i}\,$ [m]',fontsize = 19.5) 
plt.legend(['$r_{turn\,around}$',r"$r = 2.81856\times10^{12}\,m$","$r = 10^{12}\,m$","$r = 10^{11}\,m$","$r = 10^{10}\,m$"],
           prop = {'size':15}, facecolor = 'white',loc = 'center right',shadow = True,fontsize = 110) 
 
plt.title('$\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}} $', fontsize = 20, pad = 15)
plt.show()

# %%
#Analytical estimate of the turnaround radius of a shell of DM halo around the PBH of mass,
# M_PBH=100 solar mass


def r(t):
    M_PBH = 100 * M_solar
    return ((4*G*M_PBH*(t**(2)))**(1/3)) 

t = np.linspace(2.358e5, 3e12, 200000)



plt.figure(figsize = (13.5, 4.5))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 17)
plt.yticks(fontsize = 17)


plt.plot(t, r(t),'r')
plt.xlabel('$t \, $[s]',fontsize = 19.5)
plt.ylabel('$r \, $ [m]',fontsize = 19.5) 
plt.title('Variation of the Analytical estimate of the turnaround radius of the DM shell with time ', fontsize = 16, pad = 15)
plt.show()

# %%
# plot of the mass,M_DM of the DM halo as a function of time.


M_PBH = 100 * M_solar


def M_halo(M_PBH, t):
    def r_ta(t):   # Numerical estimate of the turnaround radius of the DM shells
        return ((2*G*M_PBH*(t**(2)))**(1/3)) 

    def ρ_bar(M_PBH):
        return (1/2) * (ρ_eq * Ω_cdm) * (t_eq**(3/2)) * ((2*G*M_PBH)**(3/4)) 

    return ((16*π)/3)* ρ_bar(M_PBH) * (r_ta(t)**(3/4))



print("Mass of the DM halo at matter-radiation equality is, M_DM = " '%.4e'% M_halo(M_PBH, 1.5923e12),"kg")



t= np.linspace(2.358e5, 2e12, 200000)

plt.figure(figsize = (8, 4.5))
plt.rc('lines', linewidth = 1.8)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

plt.plot(t, M_halo(M_PBH, t),'r')
plt.xlabel('$t \, $[s]',fontsize = 19.5)
plt.ylabel('$\mathrm{M_{DM}} \,$ [kg]',fontsize = 19.5) 
plt.title('$\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}} $', fontsize = 17, pad = 9 )
plt.show()


def M_DM(s):
    return  4 * Ω_cdm * M_PBH *  ((((2/3)*(s-2)*math.sqrt(s+1))+(4/3))**2)
    
print('Mass of DM halo at s_eq = ',  '%0.4e'%M_DM(1), "kg")

print("percentage_error = ", '%0.4f'%(((1.0323e+32 - 1.0314e+32)/1.0323e+32)* 100), "%" )
# Out:
# Mass of the DM halo at matter-radiation equality is, M_DM = 1.0323e+32 kg
# Mass of DM halo at s_eq =  1.0314e+32 kg
# percentage_error =  0.0872 %

# %%
M_PBH = 100 * M_solar

r_i = 1e11          #in meters

t_i = 2.358e5        # in seconds

r_ta = (r_i**4)/(16*G*M_PBH*(t_i**2))

t_ta = (r_i**6)/(128*((G*M_PBH)**2)*(t_i**3))

t_Ata = math.sqrt((r_ta**3)/(4*G*M_PBH))

print("r_ta =",'%.4e'%r_ta,"m")
print("t_ta =",'%.4e'%t_ta,"s")
print("t_Ata =",'%.4e'%t_Ata,"s")
# Out:
# r_ta = 8.4729e+09 m
# t_ta = 3.3856e+03 s
# t_Ata = 3.3856e+03 s

# %%
M_PBH = 100 * M_solar

def r(t):  # Numerical estimate of the turnaround radius of DM shells.
    return ((2*G*M_PBH*(t**2))**(1/3))

def ρ_bar(t):  # Density of DM spikes around the PBH.
        return (1/2) * (ρ_eq * Ω_cdm) * (t_eq**(3/2)) * ((2*G*M_PBH)**(3/4)) * ((r(t))**(-9/4))

t = np.linspace(t_i, t_eq, 50)


plt.figure(figsize=(8, 4.5))
plt.rc('lines', linewidth = 1.3)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

plt.loglog(t, ρ_bar(t),'g')
plt.xlabel('$t \, $[s]',fontsize = 17.5)
plt.ylabel(r'$\rho(t) \,\, \mathrm{[kg\,m^{-3}]}$ ',fontsize = 17.5) 
plt.title('$\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}} $', fontsize = 20, pad = 8)
plt.show()

# %%
# Dynamics of the various shells of DM halo around a PBH of mass, M_PBH=100 
# solar mass at different initial radii

M_PBH = 100 * M_solar


yr = 3.154e7               # in units of seconds
T_eq = (t_eq/yr)
print(T_eq)


def j(n,p):
    return [n[1], (((-G*M_PBH)/((n[0]**2))) - (n[0]/(4*p**2)))]
z0= [((1e10) ),(2.12044e4  )]                      #with initial distance r_i=1e10m
ps= np.linspace((2.358e5),(2.4e5),100000) 
ns= odeint(j,z0,ps)
zs= ns[:,0]
ps_a=ps/yr
zs_a=zs/pc

def f(u,w):
    return [u[1], (((-G*M_PBH)/((u[0]**2))) - (u[0]/(4*w**2)))]
r0= [1e11,2.12044e5]        #with initial distance r_i=1e11m
ws= np.linspace(2.358e5,7.3e5,100000)
us= odeint(f,r0,ws)
rs= us[:,0]
ws_a=ws/yr
rs_a=rs/pc

def F(U,W):
    return [U[1], (((-G*M_PBH)/((U[0]**2))) - (U[0]/(4*W**2)))]
R0= [7.745e11,(7.745e11/(2*t_i))]        #with initial distance r_i=5.8e11m
Ws= np.linspace(2.358e5, 1.96e9, 100000)
Us= odeint(F,R0,Ws)
Rs= Us[:,0]
Rs_a=Rs/pc
Ws_a=Ws/yr


def h(m,k):
    return [m[1], (((-G*M_PBH)/((m[0]**2))) - (m[0]/(4*k**2)))]                                          
y0= [1e12,2.12044e6]             #with initial distance r_i=1e12m
ks= np.linspace(2.358e5,8.5e9,100000)
ms= odeint(h,y0,ks)
ys= ms[:,0]
ys_a=ys/pc
ks_a=ks/yr


def g(v,t):
    return [v[1], (((-G*M_PBH)/((v[0]**2))) - (v[0]/(4*t**2)))]
x0= [2.1558e+12 ,(2.1558e+12/(2*t_i))]            #with initial distance r_i=2.0e+12m
ts= np.linspace(2.358e5,7.96e11,100000) 
vs= odeint(g,x0,ts)
xs= vs[:,0] 
xs_a=xs/pc
ts_a=ts/yr


def H(M,K):
    return [M[1], (((-G*M_PBH)/((M[0]**2))) - (M[0]/(4*K**2)))]                                          
Y0= [1e13,2.12044e7]             #with initial distance r_i=1e13m
Ks= np.linspace(2.358e5,1.59246e12,100000)
Ms= odeint(H,Y0,Ks)
Ys= Ms[:,0]
Ys_a=Ys/pc
Ks_a=Ks/yr



# Numerical estimate of the turnaround radius of DM shells.
def r(t):  # eq.(5) in "WIMPs and stellar-mass primordial black holes are incompatible".
    return ((2*G*M_PBH*(t**(2)))**(1/3))


t = np.linspace(2.358e5, 1.59246e12, 100000)



beta = 1e13/pc; gamma = 2e12/pc; delta = 1e12/pc; eta = 5.8e11/pc; telda = 1e11/pc ; zeta = 1e10/pc

plt.figure(figsize = (11, 6.5))

plt.rc('lines', linewidth = 1.3)


plt.loglog(Ks_a,Ys_a,'#ff7f0e')
plt.loglog(ts_a,xs_a,'#2ca02c')
plt.loglog(ks_a,ys_a,'#d62728')
plt.loglog(Ws_a,Rs_a,'#9467bd')
plt.loglog(ws_a,rs_a, '#8c564b')
plt.loglog(ps_a,zs_a,'#e377c2')

plt.loglog(t/yr,r(t)/pc,'k:')
plt.axvline(x = T_eq, color = '#04D8B2', linestyle = '--')

plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)
plt.xlabel('$t$ [yr]',fontsize = 17.5)
plt.ylabel('$r$ [pc]',fontsize = 17.5)
plt.legend( [r'$3.24\times 10^{-4}$', r'$6.48\times 10^{-5}$', r'$3.24\times 10^{-5}$', r'$1.88\times 10^{-5}$', r'$3.24\times 10^{-6}$', r'$3.24\times 10^{-7}$', r'$r_\mathrm{ta}$','$t_\mathrm{eq}\, = \,50490\,\, \mathrm{yr}$'],prop = {'size':10.1},
              loc = 'upper left',shadow = True, title = '$r_{i}\, [pc]$' ,
           facecolor = 'white',fontsize = 44)

plt.title('$\mathrm{M_\mathrm{PBH}} = 100\, \mathrm{M_{\odot}} $', fontsize = 20, pad = 8)
plt.show()
# Out:
# 50485.098287888395

# %%
# Dynamics of the various shells of DM halo around a PBH of mass, M_PBH=100 
# solar mass at different initial radii


M_PBH = 100 * M_solar           # in units of kg
T_eq = (t_eq/yr)


r_i = np.geomspace(1e11, 6e12, 5)
r_i_list = r_i.tolist()
t_f_list = [7.3e5, 1.2e7, 1.96e9, 7.96e11 , t_eq]
colors = ['#FF81C0','#FF00FF','#9A0EEA','#800080', '#650021']



def r(t):  # eq.(5) in "WIMPs and stellar-mass primordial black holes are incompatible".
    return (2 * G * M_PBH * (t**(2)))**(1/3)

t = np.linspace(2.358e5, 1.59246e12, 100000)




fig, ax = plt.subplots(1, figsize=(10.3, 7.3))
ax.loglog(t/yr, r(t)/pc,'k', linestyle = ':')
ax.axvline(x = T_eq, color = 'b', linestyle = '--')


for i, (r_i, t_f, c) in enumerate(zip(r_i_list,t_f_list, colors)):
    def j(n, p):
        return [n[1], (((-G*M_PBH)/((n[0]**2))) - (n[0]/(4*p**2)))]
    z0 = [r_i, (r_i/(2*t_i))]                      #with initial distance r_i=1e10m
    ps = np.linspace(t_i, t_f, 100000) 
    ns = odeint(j,z0,ps)
    zs = ns[:,0]
    ps = ps/yr
    zs = zs/pc
    plt.loglog(ps, zs, c = c)

    




plt.rc('lines', linewidth=1.8)
plt.xticks(fontsize= 24)
plt.yticks(fontsize= 24)

plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)

ax.tick_params(axis='x', pad= 6.8)
ax.tick_params(axis='y', pad= 6.8)

plt.xlim(1e-2, 1e5)
plt.xlabel('$t \,$ [yr]',fontsize= 29, labelpad = 15)
plt.ylabel('$r\,$ [pc]',fontsize= 29, labelpad = 15)
plt.legend( ['$r_\mathrm{ta}$','$t_\mathrm{eq}\, = \,50485\, \mathrm{yr}$'], prop = {'size':25.5},
              loc='upper left', shadow = False,  
           facecolor = 'white', fontsize= 230)
plt.title("$m_\mathrm{pbh} = 100 \, \mathrm{M_{\odot}}$", pad = 15, fontsize = 29)
plt.savefig("DMshellsaroundPBH.pdf", bbox_inches = "tight")

plt.show()

# %%
 (4 - (2 * np.sqrt(2)))/3
# Out:
# 0.3905242917512699

# %%
((3 / (8 * 3.14 * G * ρ_eq ))**(1/2)) * 0.3905
# Out:
# 1125948025265.9436

# %%
 ((4 - (2 * np.sqrt(2)))/3)**2
# Out:
# 0.15250922244783097

# %%
((3 / (8 * 3.14 * G * 1.9e-26 * (0.67**2)))**(1/2))
# Out:
# 4.5818017069736205e+17

# %%
(2.0638e+32 - 0.51 * 1.989e32)/2.0638e+32
# Out:
# 0.508484349258649

# %%
4.5818017069736205e+17 * 3.4754e-6
# Out:
# 1592359365241.612

# %%
 50 * M_solar
# Out:
# 9.945e+31

# %%
0.6 * 0.85
# Out:
# 0.51

# %%
0.51 * 1.989e32
# Out:
# 1.01439e+32

# %%
( 2.0622e+32 - 1.01439e+32 ) / 2.0622e32
# Out:
# 0.5081029967995345

# %%
2.0622e+32/1.989e32
# Out:
# 1.0368024132730016

# %%
9.4e-5/0.32
# Out:
# 0.00029374999999999996

# %%
(1.9e-26 * (0.67**2)) * ( 0.32/ ((2.9374e-4)**3)) # + (9.4e-5 /((3.33e-4)**4)))
# Out:
# 1.076871573889881e-16

# %%
2.1548e-16/2
# Out:
# 1.0774e-16

# %%
 0.85 * 0.1525 * 4
# Out:
# 0.5185

# %%
( 4 - 2* 1.414) /3
# Out:
# 0.3906666666666667

# %%
0.39066**2
# Out:
# 0.1526152356

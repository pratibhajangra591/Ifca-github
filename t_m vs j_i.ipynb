# %%
import numpy as np
import matplotlib.pyplot as plt
import imripy
from imripy import merger_system as ms
from scipy.interpolate import interp1d
from matplotlib.ticker import FormatStrFormatter
from scipy.optimize import curve_fit
from numpy import diff

plt.rcParams.update({
  "text.usetex": True,
  "font.family": "serif"
})

π = np.pi
G = 4.4959e-15            #in units of M☉^-1 pc^3 yr^-2
c = 0.3068                #in units of pc yr^-1
ρ_eq = 3.1812e3           #in units of M☉ pc^-3 with ρ_eq=2.15368e-16 kg m^-3
t_m = 13.78e9             #in units of yrs corresponding to t_0=13.78Gyr
yr = 3.154e7              # in units of seconds
t_eq = 1.59246e12/yr      # in units of yr
M_solar = 1.989e30


# Definition of the binary system 
m_bar = 1
m1 =  m_bar * ms.solar_mass_to_pc   # The central mass m1 with a mass of 1 solar masses, converted to pc


m2 = 1e-3 * ms.solar_mass_to_pc   # The secondary mass of 1e-3 solar mass converted to pc

D_luminosity = 5e8              # The distance to the system from earth as 500 Mpc



ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))



# Dark matter spike with alpha=9/4 for Primordial black holes case
r_spike = 1  # in parsecs, Choosen by choice

alpha = 9/4

rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  # This takes the value of M_sun/pc^3 and converts it to 1/pc^2

spike = imripy.halo.Spike(rho_spike, r_spike, alpha)



m_1 = 1e-3   #in units of M☉
m_2 = 2*m_1   #in units of M☉

y_1 = np.log(m_1)
y_2 = np.log(m_2)
dy  = (y_2 - y_1)

print("dy=",dy)

y_list = np.zeros(20)
m_1_list = np.zeros(len(y_list))
m_2_list = np.zeros(len(y_list))

for i in range(len(y_list)):
    m_1_list[i] = m_2_list[i] = (m_1 + ((i/4)*np.exp(dy)))

Δ_1_list = np.zeros(len(y_list))
Δ_2_list = np.zeros(len(y_list))

for i, m_1 in enumerate(m_1_list):
    Δ_1_list[i] =  Δ_2_list[i] = np.exp(m_1 + 0.5*dy) - np.exp(m_1 - 0.5*dy)
     

    

    
def a(m_1,m_2,Δ_1,Δ_2):  # for x = x_bar 
    
    f_pbh = 4.3e-3
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 2.6
        M = 1e-4     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return ( 0.0977*λ(m_1,m_2,Δ_1,Δ_2) + 0.0057*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_0 = a(m_1_list[2], m_2_list[0], Δ_1_list[2], Δ_2_list[0])


sp = ms.SystemProp(m1, m2, spike, D_luminosity)   # Create the SystemProp object describing the IMRI system

# Setting initial and final conditions of the binary evolution for an eccentric orbit

a0_array = np.linspace(1e5*a_0 , 1e4*a_0 , 6)

e0_array = 1- np.geomspace(1e-5, 0.1, 20) 

a0_list = a0_array.tolist()            

e0_list = e0_array.tolist()


a_fin = sp.r_isco()      # Choosen equal to r_icso

R_fin = sp.r_isco()      # The final condition for the evolution


plt.figure(figsize = (10, 5))
plt.rc('lines', linewidth=1)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)





for i, a0 in enumerate (a0_list):
    t_m_list = np.zeros(len(e0_list))
    j_i_list = np.zeros(len(e0_list))
    for k, e0 in enumerate (e0_list):
        a0 = a0_list[i]  
        e_0 = e0_list[k] 
        j_i_list[k] = np.sqrt(1 - (e0**2))
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a0 , e_0,  a_fin = R_fin)
        t_m_list[k] = ev_ecc.t[-1]/ms.year_to_pc
    plt.loglog(j_i_list, t_m_list)
    slope, intercept = np.polyfit(np.log(j_i_list), np.log(t_m_list), 1)
    print("intercept = ", '%0.4f'%intercept, "m =", '%0.4f'%slope)
   



    
plt.legend([ '%0.2e'%a0_list[0], '%0.2e'%a0_list[1],'%0.2e'%a0_list[2],'%0.2e'%a0_list[3],
           '%0.2e'%a0_list[4], '%0.2e'%a0_list[5],], title = '$a_{i} \, [pc]$',
            title_fontsize = 12, loc = 'upper left', prop = {"size":8})
plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} \,  M_{\odot}$ ')
plt.grid()
plt.savefig('1t_m_finalvsj_i1.pdf', bbox_inches='tight')
plt.show()
# Out:
# dy= 0.6931471805599454
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6240s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3894s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3306s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4027s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7221s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9267s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4773s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4382s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8224s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0152s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5743s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8960s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2505s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9282s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3213s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2128s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0064s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2135s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4740s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9224s
# intercept =  24.8169 m = 0.1647
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5126s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4760s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3253s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4657s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7847s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0192s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4599s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4658s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8843s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1087s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6464s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9361s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3105s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9693s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2844s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2266s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1314s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3176s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2499s
# Evolving from  1.3116462780797346e+16  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8461s
# intercept =  24.6681 m = 0.1647
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5156s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5053s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2676s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4632s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7234s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8375s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5149s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5322s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9605s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1849s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6648s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1215s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4377s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9275s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2893s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1729s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0938s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.5524s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3474s
# Evolving from  1.023723924354915e+16  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0777s
# intercept =  24.4822 m = 0.1647
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5699s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4323s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2403s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3644s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6642s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7996s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3984s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6038s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0306s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1797s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6726s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8167s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2510s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9614s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3026s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3832s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1934s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4268s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0900s
# Evolving from  7358015706300952.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0144s
# intercept =  24.2345 m = 0.1647
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6649s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5308s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3199s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4962s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6582s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9838s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3176s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4605s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7174s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0632s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6849s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8967s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1671s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0879s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1204s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1318s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0458s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0858s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2383s
# Evolving from  4478792169052753.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7951s
# intercept =  23.8622 m = 0.1647
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3002s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3800s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1882s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3325s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5501s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7305s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4450s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6580s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5838s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9176s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5269s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8008s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1793s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8690s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3515s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3930s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1599s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0896s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0444s
# Evolving from  1599568631804554.5  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9927s
# intercept =  23.0900 m = 0.1647

# %%
# Definition of the binary system 
m_bar = 1
m1 =  m_bar * ms.solar_mass_to_pc   # The central mass m1 with a mass of 1 solar masses, converted to pc


m2 = 1e-4 * ms.solar_mass_to_pc   # The secondary mass of 1e-3 solar mass converted to pc

D_luminosity = 5e8              # The distance to the system from earth as 500 Mpc



ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))



# Dark matter spike with alpha=9/4 for Primordial black holes case
r_spike = 1  # in parsecs, Choosen by choice

alpha = 9/4

rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  # This takes the value of M_sun/pc^3 and converts it to 1/pc^2

spike = imripy.halo.Spike(rho_spike, r_spike, alpha)



m_1 = 1e-4   #in units of M☉
m_2 = 2*m_1   #in units of M☉

y_1 = np.log(m_1)
y_2 = np.log(m_2)
dy  = (y_2 - y_1)

print("dy=",dy)

y_list = np.zeros(20)
m_1_list = np.zeros(len(y_list))
m_2_list = np.zeros(len(y_list))


for i in range(len(y_list)):
    m_1_list[i] = m_2_list[i] = (m_1 + ((i/4)*np.exp(dy)))
    
Δ_1_list = np.zeros(len(y_list))
Δ_2_list = np.zeros(len(y_list))

for i, m_1 in enumerate(m_1_list):
    Δ_1_list[i] =  Δ_2_list[i] = np.exp(m_1 + 0.5*dy) - np.exp(m_1 - 0.5*dy)
     

 

    
def a(m_1,m_2,Δ_1,Δ_2):  # for x =  x_bar 
    
    f_pbh = 4.3e-3
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 2.6
        M = 1e-4     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return ( 0.0977*λ(m_1,m_2,Δ_1,Δ_2) + 0.0057*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_1 = a(m_1_list[2], m_2_list[0], Δ_1_list[2], Δ_2_list[0])


sp = ms.SystemProp(m1, m2, spike, D_luminosity)   # Create the SystemProp object describing the IMRI system

# Setting initial and final conditions of the binary evolution for an eccentric orbit

a0_array = np.linspace(1e7*a_1 , 1e6*a_1 , 5)

e0_array = 1- np.geomspace(1e-5, 0.1, 20) 

a0_list = a0_array.tolist()            

e0_list = e0_array.tolist()


a_fin = sp.r_isco()      # Choosen equal to r_icso

R_fin = sp.r_isco()      # The final condition for the evolution


plt.figure(figsize = (10, 5))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)





for i, a0  in enumerate (a0_list):
    t_m_list = np.zeros(len(e0_list))
    j_i_list = np.zeros(len(e0_list))
    for k, e0 in enumerate (e0_list):
        a0 = a0_list[i]  
        e_0 = e0_list[k] 
        j_i_list[k] = np.sqrt(1 - (e0**2))
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a0 , e_0,  a_fin = R_fin)
        t_m_list[k] = ev_ecc.t[-1]/ms.year_to_pc
    plt.loglog(j_i_list, t_m_list, '')
    slope, intercept = np.polyfit(np.log(j_i_list), np.log(t_m_list), 1)
    print("intercept = ", '%0.4f'%intercept, "m =", '%0.4f'%slope)
   
    
    



    
plt.legend([ '%0.2e'%a0_list[0], '%0.2e'%a0_list[1],'%0.2e'%a0_list[2],'%0.2e'%a0_list[3],
           '%0.2e'%a0_list[4]], title = '$a_{i} \, [pc]$',
            title_fontsize = 12, loc = 'upper left', prop = {"size":8})
plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-4} \, M_{\odot}$ ')
plt.grid()
plt.savefig('2t_m_finalvsj_i.pdf', bbox_inches='tight')
plt.show()
# Out:
# dy= 0.6931471805599436
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2931s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6341s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3939s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3954s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5820s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4519s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3021s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6662s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6740s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7938s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6070s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8000s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9630s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8970s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0766s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9959s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9639s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9732s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0255s
# Evolving from  408089321326120.8  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9188s
# intercept =  24.0800 m = 0.1647
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2073s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3459s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.0573s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1995s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4716s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3640s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3034s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4210s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4119s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0326s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5718s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7203s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9558s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9309s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8255s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8837s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0209s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9042s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1650s
# Evolving from  316269224027743.6  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7716s
# intercept =  23.8888 m = 0.1647
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1641s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3619s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3276s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3316s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3639s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5297s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3572s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3960s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3551s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7546s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6172s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7889s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9685s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3827s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0615s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1718s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1405s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1442s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4337s
# Evolving from  224449126729366.47  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2003s
# intercept =  23.6316 m = 0.1647
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5864s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5944s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5342s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5790s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6306s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4263s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3874s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2451s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3748s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6834s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5995s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7624s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8016s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8649s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6845s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7010s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7431s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7295s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8542s
# Evolving from  132629029430989.27  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7491s
# intercept =  23.2370 m = 0.1647
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2551s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1486s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2643s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.0289s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1964s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2058s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1811s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2733s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2337s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3302s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3236s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6586s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8532s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8518s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6163s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7407s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6820s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7411s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7384s
# Evolving from  40808932132612.086  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5567s
# intercept =  22.3530 m = 0.1647

# %%
# Definition of the binary system 
m_bar = 1e5
m1 =  m_bar * ms.solar_mass_to_pc   # The central mass m1 with a mass of 1 solar masses, converted to pc


m2 = 10 * ms.solar_mass_to_pc   # The secondary mass of 1e-3 solar mass converted to pc

D_luminosity = 5e8              # The distance to the system from earth as 500 Mpc



ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))



# Dark matter spike with alpha=9/4 for Primordial black holes case
r_spike = 1  # in parsecs, Choosen by choice

alpha = 9/4

rho_spike =  ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  # This takes the value of M_sun/pc^3 and converts it to 1/pc^2

spike = imripy.halo.Spike(rho_spike, r_spike, alpha)



m_1 = 10   #in units of M☉
m_2 = 100   #in units of M☉

y_1 = np.log(m_1)
y_2 = np.log(m_2)
dy = (y_2-y_1)


y_list = np.zeros(10)

for i in range(len(y_list)):
    y_list[i] = (y_1 + (i/2)*dy)
    

M_1_list = np.zeros(len(y_list))
M_2_list = np.zeros(len(y_list))

for i, y in enumerate(y_list):
    M_1_list[i] = (np.ceil(np.exp(y)))-1
    M_2_list[i] = (np.ceil(np.exp(y)))-1
    

            
m_1_list = [int(M_1) for M_1 in M_1_list]
m_2_list = [int(M_2) for M_2 in M_2_list]

    
Δ_1_list = np.zeros(len(y_list))
Δ_2_list = np.zeros(len(y_list))

for i, y in enumerate(y_list):
    Δ_1_list[i] = np.exp(y + 0.5*dy) - np.exp(y - 0.5*dy)
    Δ_2_list[i] = np.exp(y + 0.5*dy) - np.exp(y - 0.5*dy) 

    
    
def a(m_1,m_2,Δ_1,Δ_2):  # For x = x_bar 
    
    f_pbh = 4.3e-3
    f = 0.85 * f_pbh
        
          
    def P(m): #Powerlaw PBH mass distribution
        α = 2.6
        M = 1e-4     #in units of M☉
        return ((α-1)/M) * ((m/M)**(-α))

    
    def f_(m):
        return f*P(m)
    
    def f_b(m_1,m_2):
        return  f_(m_1)+f_(m_2)
    
    def x̄(m_1,m_2,Δ_1,Δ_2):
        return (((3*(m_1+m_2))/(8*π*ρ_eq*f_b(m_1,m_2)*np.sqrt(Δ_1*Δ_2)))**(1/3))
   
    def λ(m_1,m_2,Δ_1,Δ_2):
        return (8*π*ρ_eq*(x̄(m_1,m_2,Δ_1,Δ_2)**3))/(3*(m_1 + m_2))

    
    return ( 0.0977*λ(m_1,m_2,Δ_1,Δ_2) + 0.0057*(λ(m_1,m_2,Δ_1,Δ_2)**2) ) * x̄(m_1,m_2,Δ_1,Δ_2)





a_2 = a(m_1_list[0], m_2_list[8], Δ_1_list[0], Δ_2_list[8])


sp = ms.SystemProp(m1, m2, spike, D_luminosity)   # Create the SystemProp object describing the IMRI system

# Setting initial and final conditions of the binary evolution for an eccentric orbit

a0_array = np.linspace(1e-8*a_2 , 1e-9*a_2 , 5)

e0_array = 1- np.geomspace(0.1, 1e-5, 20) 

a0_list = a0_array.tolist()            

e0_list = e0_array.tolist()


a_fin = sp.r_isco()      # Choosen equal to r_icso

R_fin = sp.r_isco()      # The final condition for the evolution


plt.figure(figsize = (10, 5))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(which='both', right=True, top=True)




for i,  a0  in enumerate (a0_list):
    t_m_list = np.zeros(len(e0_list))
    j_i_list = np.zeros(len(e0_list))
    for k, e0 in enumerate (e0_list):
        a0 = a0_list[i]  
        e_0 = e0_list[k] 
        j_i_list[k] = np.sqrt(1 - (e0**2))
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a0 , e_0,  a_fin = R_fin)
        t_m_list[k] = ev_ecc.t[-1]/ms.year_to_pc
    plt.loglog(j_i_list, t_m_list, '')
    slope, intercept = np.polyfit(np.log(j_i_list), np.log(t_m_list), 1)
    print("intercept = ", '%0.4f'%intercept, "m =", '%0.4f'%slope)
   
    



    
plt.legend([ '%0.2e'%a0_list[0], '%0.2e'%a0_list[1],'%0.2e'%a0_list[2],'%0.2e'%a0_list[3],
           '%0.2e'%a0_list[4]], title = '$a_{i} \, [pc]$',
            title_fontsize = 12, loc = 'upper left', prop = {"size":8})
plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 10^{5} \, M_{\odot}$ and $m_{2}= 10 \, M_{\odot}$ ')
plt.grid()
plt.savefig('3t_m_finalvsj_i.pdf', bbox_inches='tight')
plt.show()
# Out:
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8827s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933973  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3571s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4013s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0799s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4720s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3724s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0821s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4438s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8924s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6232s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0781s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8434s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5257s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4548s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9598s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7049s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4152s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4545s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6245s
# Evolving from  4348546015286002.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6821s
# intercept =  31.6110 m = 0.1647
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9618s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933973  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2693s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3446s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1427s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.5157s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4060s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9855s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.9607s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4443s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0748s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.6179s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2893s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9612s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8809s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4739s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2929s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8118s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8543s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6093s
# Evolving from  3370123161846652.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6809s
# intercept =  31.4198 m = 0.1647
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8788s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933973  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3509s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2661s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0752s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1143s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4399s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9602s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4924s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0367s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7836s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3006s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9091s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5470s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5594s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2276s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9127s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5308s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3637s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5310s
# Evolving from  2391700308407301.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.5732s
# intercept =  31.1626 m = 0.1647
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9392s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9384151788933973  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2816s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.4664s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2525s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2875s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.3468s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0526s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.5839s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9224s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6745s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1011s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9176s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4376s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4466s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9556s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7872s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4019s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.2479s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4694s
# Evolving from  1413277454967950.5  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4011s
# intercept =  30.7681 m = 0.1647
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:153: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**3 / a**5  / (1. - e**2)**(7./2.) * (1. + 73./24. * e**2 + 37./96. * e**4)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in double_scalars
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.9486s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9384151788933973  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1284s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2842s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.0097s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2370s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1207s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8827s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.1990s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.8396s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7006s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 4.2036s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7127s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4812s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4793s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.6058s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.7073s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3910s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.1704s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.4663s
# Evolving from  434854601528600.25  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 3.3637s
# intercept =  29.8841 m = 0.1647

# %%
# Comparison of the final time of merger of IMRIPY system using halo spike = 0 and the analytical 
# expression for the time of merger.





# Definition of the binary system 
m_bar = 1
m1 =  m_bar * ms.solar_mass_to_pc   # The central mass m1 with a mass of 1 solar masses, converted to pc


m2 = 1e-3 * ms.solar_mass_to_pc   # The secondary mass of 1e-3 solar mass converted to pc


D_luminosity = 5e8              # The distance to the system from earth as 500 Mpc



ρ_bar = (ρ_eq/2) * (t_eq**(3/2)) * ((2 * G * m_bar)**(3/4))




r_spike = 1      # in parsecs, Choosen by choice

alpha = 9/4

rho_spike =  0 * ρ_bar * (r_spike**(-alpha)) * ms.solar_mass_to_pc  # This takes the value of M_sun/pc^3 and converts it to 1/pc^2

spike = imripy.halo.Spike(rho_spike, r_spike, alpha)





sp = ms.SystemProp(m1, m2, spike, D_luminosity)   # Create the SystemProp object describing the IMRI system

# Setting initial and final conditions of the binary evolution for an eccentric orbit

a0_array = np.linspace(1e5*a_0 , 1e3*a_0 , 6)

e0_array = 1- np.geomspace(1e-5, 0.1, 20)

a0_list = a0_array.tolist()            

e0_list = e0_array.tolist()


a_fin = sp.r_isco()      # Choosen equal to r_icso

R_fin = sp.r_isco()      # The final condition for the evolution

M_1 = 1      # in units of solar mass
M_2 = 1e-3   # in units of solar mass

def t_merger_final(a0,e0):
    return ((3/85) * (a0**4) * (np.sqrt(1 - (e0**2))**7) * (c**5)) / ((G**3) * M_1 * M_2 *(M_1 + M_2))



plt.figure(figsize = (10, 5))

colors = ['C0','C1','C2','C3', 'C4','C5']


for i, (a0, color) in enumerate (zip(a0_list,colors)):
    t_m_list = np.zeros(len(e0_list))
    j_i_list = np.zeros(len(e0_list))
    t_merger_final_list = np.zeros(len(e0_list))
    for k, e0 in enumerate (e0_list):
        a0 = a0_list[i]  
        e_0 = e0_list[k] 
        j_i_list[k] = np.sqrt(1 - (e0**2))
        t_merger_final_list[k] = t_merger_final(a0, e0)
        ev_ecc = imripy.inspiral.Classic.Evolve(sp, a0 , e_0,  a_fin = R_fin)
        t_m_list[k] = ev_ecc.t[-1]/ms.year_to_pc
    plt.loglog(j_i_list, t_merger_final_list, color = color)
    plt.loglog(j_i_list, t_m_list, color = color, linestyle = '--')



plt.legend([ 'Analytic', 'IMRIPY spike = 0'], title = 'Without halos',
            title_fontsize = 12, loc = (0.8,0.3), prop = {"size":8})
plt.xlabel('$j_{i}$', fontsize = 13)
plt.ylabel('final merger time / yr', fontsize = 12)
plt.title('$m_{1} = 1 \, M_{\odot}$ and $m_{2}= 10^{-3} M_{\odot}$ ')
plt.grid()
plt.savefig('t_m_agreement.pdf',bbox_inches='tight')
plt.show()
# Out:
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4756s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5414s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4393s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5089s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4595s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4855s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4392s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4265s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4293s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3309s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3598s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2650s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3486s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3138s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2529s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2557s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2204s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1859s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2052s
# Evolving from  1.5995686318045546e+16  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1111s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4954s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5273s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5370s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4787s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4924s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4295s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4226s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3943s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4751s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3570s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4293s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3769s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3486s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3308s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2976s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2658s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2535s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1522s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1859s
# Evolving from  1.2828540427072528e+16  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1413s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5119s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5087s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5063s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5100s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5861s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5236s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4326s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5256s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4569s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3264s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3969s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3501s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2646s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2865s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3096s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2515s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2632s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3473s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2126s
# Evolving from  9661394536099510.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1456s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5287s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5329s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4958s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5227s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4979s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5074s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5904s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4668s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4557s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3879s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3712s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3804s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3863s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2643s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2415s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2513s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2932s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1565s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1751s
# Evolving from  6494248645126492.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1260s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5039s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5372s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4940s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4902s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5734s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5010s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4699s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4548s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4301s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3611s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3429s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3448s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3695s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3257s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2785s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2442s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2343s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2657s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1396s
# Evolving from  3327102754153474.0  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1083s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.99999  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:335: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/halo.py:321: RuntimeWarning: invalid value encountered in double_scalars
#   return np.where(r > self.r_min, self.rho_spike * (self.r_spike/r)**self.alpha, 0.)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:337: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi * quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5384s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9999837622326081  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5186s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9999736334910126  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.5146s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9999571866760129  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4960s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9999304807203823  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4780s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9998871162108315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4794s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9998167019289168  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4172s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9997023648558369  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4187s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9995167069761428  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.4523s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9992152400296486  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3414s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9987257250142969  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3700s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9979308619188852  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3602s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9966401817137163  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3084s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9945444052188315  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.3124s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9911413320958992  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:172: RuntimeWarning: invalid value encountered in double_scalars
#   return -32./5. * sp.m_reduced(a)**2 * sp.m_total(a)**(5./2.) / a**(7./2.)  / (1. - e**2)**2 * (1. + 7./8.*e**2)
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:361: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.-e**2)**(3./2.)/2./np.pi *np.sqrt(sp.m_total(a) * a*(1.-e**2)) *  quad(integrand, 0., 2.*np.pi, limit = 100)[0]
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:359: RuntimeWarning: invalid value encountered in sqrt
#   v_s = np.sqrt(sp.m_total(a) *(2./r - 1./a))
# /home/pratibhajangra/imripy/src/imripy/inspiral.py:133: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(a * (1-e**2) * sp.m_total(a) * sp.m_reduced(a)**2 )
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2454s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9856155011171234  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2273s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9766427853090988  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.2529s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9620730980926775  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1842s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9384151788933974  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1711s
# Evolving from  159956863180455.47  to  1.0 r_isco  with initial eccentricity 0.9  with  Options: accretion = False, haloPhaseSpaceDescription = False, accuracy = 1.0e-08
# Required step size is less than spacing between numbers.
#  -> Evolution took 1.1039s
